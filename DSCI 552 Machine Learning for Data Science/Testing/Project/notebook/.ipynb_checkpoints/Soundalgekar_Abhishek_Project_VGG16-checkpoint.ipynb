# %% [markdown]
# <center><h1>Soundalgekar_Abhishek_Project_VGG16</h1></center>

# %% [markdown]
# Name: Abhishek Soundalgekar
# <br>
# Github Username: ABHISHEK SOUNDALGEKAR
# <br>
# USC ID: 2089011000

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.metrics import classification_report
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
DATA_ROOT   = "../data/WasteSplit"
TRAIN_PATH  = os.path.join(DATA_ROOT, "train")
VALID_PATH  = os.path.join(DATA_ROOT, "val")
TEST_PATH   = os.path.join(DATA_ROOT, "test")

IMG_SIZE    = (224, 224)
BATCH_SZ    = 5
MAX_EPOCHS  = 100
LR          = 1e-4
PATIENCE    = 40
L2_FACTOR   = 0.01
DROPOUT_RATE = 0.2

# --- Data Augmentation & Generators ---
augmenter = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    brightness_range=(0.8, 1.2),
    horizontal_flip=True
)

train_loader = augmenter.flow_from_directory(
    TRAIN_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SZ,
    class_mode='categorical',
    shuffle=True
)
valid_loader = augmenter.flow_from_directory(
    VALID_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SZ,
    class_mode='categorical',
    shuffle=False
)
test_loader = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input
).flow_from_directory(
    TEST_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SZ,
    class_mode='categorical',
    shuffle=False
)

#Load VGG16 backbone
backbone = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=IMG_SIZE + (3,)
)
backbone.trainable = False

#new classification head
x = backbone.output
x = GlobalAveragePooling2D()(x)
# Dense block 1
x = Dense(256, activation='relu', kernel_regularizer=l2(L2_FACTOR))(x)
x = BatchNormalization()(x)
# Dense block 2
x = Dense(128, activation='relu', kernel_regularizer=l2(L2_FACTOR))(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT_RATE)(x)
# Dense block 3
x = Dense(64, activation='relu', kernel_regularizer=l2(L2_FACTOR))(x)
x = BatchNormalization()(x)

#softmax layer for all classes
num_classes = train_loader.num_classes
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=backbone.input, outputs=predictions)

model.compile(
    optimizer=Adam(learning_rate=LR),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

early_stopper = EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE,
    restore_best_weights=True
)

history = model.fit(
    train_loader,
    validation_data=valid_loader,
    epochs=MAX_EPOCHS,
    callbacks=[early_stopper]
)

test_loss, test_acc = model.evaluate(test_loader)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Found 3323 images belonging to 9 classes.
# Found 710 images belonging to 9 classes.
# Found 719 images belonging to 9 classes.
# Epoch 1/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1044s 2s/step - accuracy: 0.1610 - loss: 8.4483 - val_accuracy: 0.3437 - val_loss: 7.7222
# Epoch 2/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1018s 2s/step - accuracy: 0.3032 - loss: 7.7022 - val_accuracy: 0.4577 - val_loss: 7.1322
# Epoch 3/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 991s 1s/step - accuracy: 0.3788 - loss: 7.2778 - val_accuracy: 0.5479 - val_loss: 6.7923
# Epoch 4/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1000s 2s/step - accuracy: 0.4618 - loss: 6.9138 - val_accuracy: 0.5901 - val_loss: 6.6140
# Epoch 5/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1015s 2s/step - accuracy: 0.4920 - loss: 6.6268 - val_accuracy: 0.6000 - val_loss: 6.3040
# Epoch 6/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 
100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1161s 2s/step - accuracy: 0.7498 - loss: 1.6977 - val_accuracy: 0.7606 - val_loss: 1.6685
# Epoch 49/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1160s 2s/step - accuracy: 0.7597 - loss: 1.6666 - val_accuracy: 0.7690 - val_loss: 1.6004
# Epoch 50/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1157s 2s/step - accuracy: 0.7330 - loss: 1.6750 - val_accuracy: 0.7577 - val_loss: 1.5777
# Epoch 51/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1132s 2s/step - accuracy: 0.7430 - loss: 1.6396 - val_accuracy: 0.7845 - val_loss: 1.5294
# Epoch 52/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1132s 2s/step - accuracy: 0.7406 - loss: 1.6231 - val_accuracy: 0.7704 - val_loss: 1.5225
# Epoch 53/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 5781s 9s/step - accuracy: 0.7510 - loss: 1.5660 - val_accuracy: 0.7662 - val_loss: 1.4745
# Epoch 54/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 2161s 3s/step - accuracy: 0.7584 - loss: 1.5288 - val_accuracy: 0.7718 - val_loss: 1.4712
# Epoch 55/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1093s 2s/step - accuracy: 0.7491 - loss: 1.5295 - val_accuracy: 0.7521 - val_loss: 1.4587
# Epoch 56/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1129s 2s/step - accuracy: 0.7534 - loss: 1.4820 - val_accuracy: 0.7845 - val_loss: 1.3831
# Epoch 57/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1111s 2s/step - accuracy: 0.7709 - loss: 1.4597 - val_accuracy: 0.7662 - val_loss: 1.4132
# Epoch 58/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1073s 2s/step - accuracy: 0.7451 - loss: 1.4583 - val_accuracy: 0.7732 - val_loss: 1.3876
# Epoch 59/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1073s 2s/step - accuracy: 0.7688 - loss: 1.3883 - val_accuracy: 0.7718 - val_loss: 1.3627
# Epoch 60/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1010s 2s/step - accuracy: 0.7645 - loss: 1.3867 - val_accuracy: 0.7859 - val_loss: 1.3087
# Epoch 61/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1048s 2s/step - accuracy: 0.7562 - loss: 1.3751 - val_accuracy: 0.7620 - val_loss: 1.3434
# Epoch 62/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 992s 1s/step - accuracy: 0.7620 - loss: 1.3570 - val_accuracy: 0.7746 - val_loss: 1.2798
# Epoch 63/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1006s 2s/step - accuracy: 0.7697 - loss: 1.3489 - val_accuracy: 0.7732 - val_loss: 1.2654
# Epoch 64/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1001s 2s/step - accuracy: 0.7625 - loss: 1.3187 - val_accuracy: 0.7859 - val_loss: 1.2239
# Epoch 65/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1158s 2s/step - accuracy: 0.7641 - loss: 1.2958 - val_accuracy: 0.7775 - val_loss: 1.2572
# Epoch 66/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 3448s 5s/step - accuracy: 0.7786 - loss: 1.2713 - val_accuracy: 0.7831 - val_loss: 1.2200
# Epoch 67/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 1127s 2s/step - accuracy: 0.7823 - loss: 1.2609 - val_accuracy: 0.7845 - val_loss: 1.2257
# Epoch 68/100
# 626/665 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.7744 - loss: 1.2373
# KeyboardInterrupt
