# %% [markdown]
# <center><h1>Soundalgekar_Abhishek_Project</h1></center>

# %% [markdown]
# Name: Abhishek Soundalgekar
# <br>
# Github Username: ABHISHEK SOUNDALGEKAR
# <br>
# USC ID: 2089011000

# %% [markdown]
# Import Packages

# %%
pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from -r ../requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from -r ../requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: seaborn in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from -r ../requirements.txt (line 3)) (0.13.2)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from -r ../requirements.txt (line 4)) (3.9.4)
# Collecting statsmodels (from -r ../requirements.txt (line 5))
#   Downloading statsmodels-0.14.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting bootstrapped (from -r ../requirements.txt (line 6))
#   Downloading bootstrapped-0.0.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from -r ../requirements.txt (line 7)) (1.6.1)
# Collecting xgboost (from -r ../requirements.txt (line 8))
#   Downloading xgboost-2.1.4-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: tensorflow in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from -r ../requirements.txt (line 9)) (2.16.2)
# Requirement already satisfied: pillow in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from -r ../requirements.txt (line 10)) (11.3.0)
# Collecting efficientnet (from -r ../requirements.txt (line 11))
#   Downloading efficientnet-1.1.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from pandas->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from pandas->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from pandas->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (3.2.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (6.5.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from statsmodels->-r ../requirements.txt (line 5)) (1.13.1)
# Collecting patsy>=0.5.6 (from statsmodels->-r ../requirements.txt (line 5))
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from scikit-learn->-r ../requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from scikit-learn->-r ../requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (2.32.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (1.73.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (3.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorflow->-r ../requirements.txt (line 9)) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow->-r ../requirements.txt (line 9)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow->-r ../requirements.txt (line 9)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow->-r ../requirements.txt (line 9)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow->-r ../requirements.txt (line 9)) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow->-r ../requirements.txt (line 9)) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow->-r ../requirements.txt (line 9)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow->-r ../requirements.txt (line 9)) (3.1.3)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from efficientnet->-r ../requirements.txt (line 11))
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting scikit-image (from efficientnet->-r ../requirements.txt (line 11))
#   Downloading scikit_image-0.24.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (14 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow->-r ../requirements.txt (line 9)) (0.45.1)
# Requirement already satisfied: zipp>=3.1.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->-r ../requirements.txt (line 4)) (3.23.0)
# Requirement already satisfied: rich in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow->-r ../requirements.txt (line 9)) (14.0.0)
# Requirement already satisfied: namex in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow->-r ../requirements.txt (line 9)) (0.1.0)
# Requirement already satisfied: optree in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow->-r ../requirements.txt (line 9)) (0.16.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow->-r ../requirements.txt (line 9)) (8.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow->-r ../requirements.txt (line 9)) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from rich->keras>=3.0.0->tensorflow->-r ../requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from rich->keras>=3.0.0->tensorflow->-r ../requirements.txt (line 9)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow->-r ../requirements.txt (line 9)) (0.1.2)
# Collecting networkx>=2.8 (from scikit-image->efficientnet->-r ../requirements.txt (line 11))
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting imageio>=2.33 (from scikit-image->efficientnet->-r ../requirements.txt (line 11))
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->efficientnet->-r ../requirements.txt (line 11))
#   Downloading tifffile-2024.8.30-py3-none-any.whl.metadata (31 kB)
# Collecting lazy-loader>=0.4 (from scikit-image->efficientnet->-r ../requirements.txt (line 11))
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Downloading statsmodels-0.14.5-cp39-cp39-macosx_11_0_arm64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 31.4 MB/s eta 0:00:00a 0:00:01
# Downloading xgboost-2.1.4-py3-none-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 28.0 MB/s eta 0:00:00
# Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading scikit_image-0.24.0-cp39-cp39-macosx_12_0_arm64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 31.1 MB/s eta 0:00:00a 0:00:01
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.3 MB/s eta 0:00:00
# Downloading tifffile-2024.8.30-py3-none-any.whl (227 kB)
# Building wheels for collected packages: bootstrapped
#   DEPRECATION: Building 'bootstrapped' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'bootstrapped'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for bootstrapped (setup.py) ... done
#   Created wheel for bootstrapped: filename=bootstrapped-0.0.2-py2.py3-none-any.whl size=13971 sha256=b19ea91ae2c0b57b2723659acbfcf47c47cdf7f04ef64240eec5914f16af5e06
#   Stored in directory: /Users/agam/Library/Caches/pip/wheels/a9/7b/e9/000ad8cb18a35a7d68051b362c96a867cd24b7b0c7b478329d
# Successfully built bootstrapped
# Installing collected packages: tifffile, patsy, networkx, lazy-loader, imageio, xgboost, scikit-image, keras-applications, statsmodels, efficientnet, bootstrapped
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [bootstrapped] [statsmodels]]
# Successfully installed bootstrapped-0.0.2 efficientnet-1.1.1 imageio-2.37.0 keras-applications-1.0.8 lazy-loader-0.4 networkx-3.2.1 patsy-1.0.1 scikit-image-0.24.0 statsmodels-0.14.5 tifffile-2024.8.30 xgboost-2.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import random
import shutil
from pathlib import Path
from typing import Tuple, Dict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import (ResNet50,ResNet101,VGG16,EfficientNetB0)
from tensorflow.keras.layers import (Input,GlobalAveragePooling2D,Dense,Dropout,BatchNormalization,Activation)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, Adam as AdamOpt
from tensorflow.keras.callbacks import (EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
)
from tensorflow.keras.regularizers import l2
from sklearn.metrics import classification_report

import efficientnet.tfkeras as efn
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.regularizers import l2
from tensorflow.keras import Model
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.metrics import AUC
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # First Model - Resnet50 #

# %%
from pathlib import Path
import shutil, random

def split_into_train_val_test(src_root: Path, dst_root: Path, train_frac=0.8, val_frac_of_train=0.2, seed=123):
    random.seed(seed)
    for cls in sorted((src_root).iterdir()):
        if not cls.is_dir(): continue
        imgs = sorted(cls.iterdir())
        n = len(imgs)
        split_pt = int(train_frac * n)
        train_imgs = imgs[:split_pt]
        test_imgs  = imgs[split_pt:]

        # from train_imgs, take a random val set
        n_val = int(val_frac_of_train * len(train_imgs))
        val_imgs = random.sample(train_imgs, n_val)
        train_imgs = [i for i in train_imgs if i not in val_imgs]

        for subset, files in [("train", train_imgs), ("val", val_imgs), ("test", test_imgs)]:
            for p in files:
                dst = dst_root / subset / cls.name
                dst.mkdir(parents=True, exist_ok=True)
                shutil.copy2(p, dst / p.name)

# Usage:
split_into_train_val_test(
    src_root=Path("../data/RealWaste"),       # your original data folder
    dst_root=Path("../data/WasteSplit")
)

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def preprocess_with_contrast(x):
    # x is a float32 image in [0,255]
    x = tf.image.random_contrast(x, lower=0.8, upper=1.2)
    return tf.keras.applications.resnet50.preprocess_input(x)

augmentor = ImageDataGenerator(
    preprocessing_function=preprocess_with_contrast,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    brightness_range=(0.8, 1.2),
    horizontal_flip=True
)

# %%
DATA_ROOT: Path = Path("../data/WasteSplit")
IMG_DIMS: Tuple[int,int] = (224, 224)
BATCH_SZ: int = 5
NUM_EPOCHS: int = 100

#Augmentation + ResNet50 Preprocessing
augmenter = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input,
    rotation_range=20,            
    width_shift_range=0.2,        
    height_shift_range=0.2,       
    zoom_range=0.2,               
    brightness_range=(0.8, 1.2),  
    horizontal_flip=True
)

def make_generator(
    split: str,
    batch_size: int = BATCH_SZ,
    img_size: Tuple[int,int] = IMG_DIMS,
    shuffle: bool = True
) -> tf.keras.preprocessing.image.DirectoryIterator:
    folder = DATA_ROOT / split
    return augmenter.flow_from_directory(
        directory=str(folder),
        target_size=img_size,
        batch_size=batch_size,
        class_mode="categorical",
        shuffle=shuffle
    )

train_generator = make_generator("train",  batch_size=BATCH_SZ, img_size=IMG_DIMS, shuffle=True)
val_generator   = make_generator("val",    batch_size=BATCH_SZ, img_size=IMG_DIMS, shuffle=False)
test_generator  = make_generator("test",   batch_size=BATCH_SZ, img_size=IMG_DIMS, shuffle=False)
# Out:
# Found 3042 images belonging to 9 classes.
# Found 756 images belonging to 9 classes.
# Found 954 images belonging to 9 classes.

# %%
root_path    = Path("../data/WasteSplit")
train_path   = root_path / "train"
height_px    = 224
width_px     = 224
channels_cnt = 3
input_dims   = (height_px, width_px, channels_cnt)

#Class Count
label_count = sum(1 for d in train_path.iterdir() if d.is_dir())

#Freeze Pretrained Backbone
resnet_core = ResNet50(
    include_top=False,
    weights="imagenet",
    input_shape=input_dims,
    name="resnet50_core"
)
resnet_core.trainable = False

l2_penalty = l2(1e-2)

#Dense → BatchNorm → ReLU Helper
def dense_norm_relu(tensor, units, identifier: str):
    y = Dense(units, kernel_regularizer=l2_penalty, name=f"{identifier}_dense")(tensor)
    y = BatchNormalization(name=f"{identifier}_bn")(y)
    return Activation("relu", name=f"{identifier}_act")(y)

#Classification Head
x = GlobalAveragePooling2D(name="avg_pool")(resnet_core.output)
x = dense_norm_relu(x, 256, "blockA")
x = dense_norm_relu(x, 128, "blockB")
x = Dropout(0.2, name="blockC_dropout")(x)
x = dense_norm_relu(x, 64,  "blockC")

# Final prediction layer
output_layer = Dense(label_count, activation="softmax", name="predictions")(x)

waste_classifier = Model(
    inputs=resnet_core.input,
    outputs=output_layer,
    name="WasteSplit_ResNet50"
)
waste_classifier.summary()
# Out:
# 2025-07-28 19:32:33.438638: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2025-07-28 19:32:33.438792: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 24.00 GB
# 2025-07-28 19:32:33.438798: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 8.00 GB
# 2025-07-28 19:32:33.439017: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-07-28 19:32:33.439039: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "WasteSplit_ResNet50"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 112, 112,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 112, 112,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 114, 114,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 56, 56,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 56, 56,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 56, 56,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 56, 56,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 56, 56,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 56, 56,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 56, 56,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 56, 56,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 56, 56,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 56, 56,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 56, 56,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 56, 56,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 56, 56,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 56, 56,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 56, 56,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 56, 56,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 56, 56,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 56, 56,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 56, 56,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 56, 56,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 56, 56,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 56, 56,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 56, 56,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 56, 56,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 28, 28,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 28, 28,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 28, 28,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 28, 28,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 28, 28,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 28, 28,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 28, 28,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 28, 28,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 28, 28,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 28, 28,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 28, 28,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 28, 28,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 28, 28,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 28, 28,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 28, 28,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 28, 28,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 28, 28,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 28, 28,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 28, 28,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 28, 28,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 28, 28,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 28, 28,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 28, 28,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 28, 28,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 28, 28,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 28, 28,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 28, 28,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 14, 14,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 14, 14,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 14, 14,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 14, 14,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 14, 14,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 14, 14,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 14, 14,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 14, 14,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 14, 14,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 14, 14,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 14, 14,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 14, 14,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 14, 14,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 14, 14,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 14, 14,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 14, 14,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 14, 14,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 14, 14,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 14, 14,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 14, 14,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 14, 14,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 14, 14,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 14, 14,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 14, 14,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 14, 14,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 14, 14,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 14, 14,    │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 7, 7, 512) │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 7, 7,      │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 7, 7,      │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 7, 7,      │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 7, 7,      │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 7, 7, 512) │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 7, 7,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 7, 7,      │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 7, 7, 512) │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 7, 7,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 7, 7,      │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 2048)      │          0 │ conv5_block3_out… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ blockA_dense        │ (None, 256)       │    524,544 │ avg_pool[0][0]    │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ blockA_bn           │ (None, 256)       │      1,024 │ blockA_dense[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ blockA_act          │ (None, 256)       │          0 │ blockA_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ blockB_dense        │ (None, 128)       │     32,896 │ blockA_act[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ blockB_bn           │ (None, 128)       │        512 │ blockB_dense[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ blockB_act          │ (None, 128)       │          0 │ blockB_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ blockC_dropout      │ (None, 128)       │          0 │ blockB_act[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ blockC_dense        │ (None, 64)        │      8,256 │ blockC_dropout[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ blockC_bn           │ (None, 64)        │        256 │ blockC_dense[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ blockC_act          │ (None, 64)        │          0 │ blockC_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions (Dense) │ (None, 9)         │        585 │ blockC_act[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,155,785 (92.15 MB)
#  Trainable params: 567,177 (2.16 MB)
#  Non-trainable params: 23,588,608 (89.98 MB)

# %%
from tensorflow.keras.optimizers import Adam as OptimizerAdam
from tensorflow.keras.losses     import CategoricalCrossentropy
from tensorflow.keras.metrics    import CategoricalAccuracy

lr_value      = 1e-4
adam_solver   = OptimizerAdam(learning_rate=lr_value)
ce_loss       = CategoricalCrossentropy()
cat_accuracy  = CategoricalAccuracy(name="categorical_accuracy")

classification_engine = waste_classifier
classification_engine.compile(
    optimizer=adam_solver,
    loss=ce_loss,
    metrics=[cat_accuracy]
)

# %%
from tensorflow.keras.metrics import AUC
from tensorflow.keras.callbacks import Callback, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, BatchNormalization, Dropout, Activation
)
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
import tensorflow as tf
from pathlib import Path

DATA_DIR = Path("../data/WasteSplit")
H, W     = 224, 224
BATCH    = 5
EPOCHS   = 100
LR       = 1e-4
L2_REG   = 1e-2
PATIENCE = 40

def make_stream(subdir, augment=False):
    args = dict(
        preprocessing_function=tf.keras.applications.resnet.preprocess_input,
        rotation_range=20, width_shift_range=0.2,
        height_shift_range=0.2, zoom_range=0.2,
        brightness_range=(0.8,1.2), horizontal_flip=True
    ) if augment else dict(preprocessing_function=tf.keras.applications.resnet.preprocess_input)
    gen = ImageDataGenerator(**args)
    return gen.flow_from_directory(
        DATA_DIR / subdir,
        target_size=(H, W),
        batch_size=BATCH,
        class_mode="categorical",
        shuffle=(subdir == "train")
    )

train_stream      = make_stream("train", augment=True)
validation_stream = make_stream("val",   augment=True)

# model with AUC
backbone = ResNet50(include_top=False, weights="imagenet", input_shape=(H, W, 3))
backbone.trainable = False

def dense_block(x, units, tag):
    x = Dense(units, kernel_regularizer=l2(L2_REG), name=f"{tag}_dense")(x)
    x = BatchNormalization(name=f"{tag}_bn")(x)
    return Activation("relu", name=f"{tag}_act")(x)

x = GlobalAveragePooling2D()(backbone.output)
x = dense_block(x, 256, "blk1")
x = dense_block(x, 128, "blk2")
x = Dropout(0.2)(x)
x = dense_block(x, 64,  "blk3")
outputs = Dense(train_stream.num_classes, activation="softmax")(x)

model = Model(backbone.input, outputs, name="resnet50_waste")
model.compile(
    optimizer=Adam(LR),
    loss="categorical_crossentropy",
    metrics=["accuracy", AUC(name="auc")]
)

#Callbacks
stop_callback = EarlyStopping(
    monitor="val_loss",
    patience=PATIENCE,
    restore_best_weights=True,
    verbose=1
)

class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        logs["learning_rate"] = float(self.model.optimizer.learning_rate.numpy())

lr_logger = LearningRateLogger()

#Train with verbose=1
history = model.fit(
    train_stream,
    validation_data=validation_stream,
    epochs=EPOCHS,
    callbacks=[stop_callback, lr_logger],
    verbose=1
)
# Out:
# Found 3042 images belonging to 9 classes.
# Found 756 images belonging to 9 classes.
# Epoch 1/100
# /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2025-07-28 19:32:47.040319: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 33s 48ms/step - accuracy: 0.1787 - auc: 0.5790 - loss: 9.2958 - val_accuracy: 0.5661 - val_auc: 0.8887 - val_loss: 7.9778 - learning_rate: 1.0000e-04
# Epoch 2/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.4674 - auc: 0.8350 - loss: 8.1087 - val_accuracy: 0.6746 - val_auc: 0.9365 - val_loss: 7.2065 - learning_rate: 1.0000e-04
# Epoch 3/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.5643 - auc: 0.8917 - loss: 7.3866 - val_accuracy: 0.7156 - val_auc: 0.9486 - val_loss: 6.6207 - learning_rate: 1.0000e-04
# Epoch 4/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.5828 - auc: 0.9058 - loss: 6.8423 - val_accuracy: 0.7381 - val_auc: 0.9599 - val_loss: 6.0738 - learning_rate: 1.0000e-04
# Epoch 5/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.6213 - auc: 0.9218 - loss: 6.2829 - val_accuracy: 0.7566 - val_auc: 0.9625 - val_loss: 5.6048 - learning_rate: 1.0000e-04
# Epoch 6/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.6476 - auc: 0.9301 - loss: 5.8068 - val_accuracy: 0.7897 - val_auc: 0.9689 - val_loss: 5.1466 - learning_rate: 1.0000e-04
# Epoch 7/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.6710 - auc: 0.9395 - loss: 5.3537 - val_accuracy: 0.7817 - val_auc: 0.9726 - val_loss: 4.7518 - learning_rate: 1.0000e-04
# Epoch 8/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.6985 - auc: 0.9494 - loss: 4.9172 - val_accuracy: 0.7884 - val_auc: 0.9736 - val_loss: 4.4081 - learning_rate: 1.0000e-04
# Epoch 9/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.7080 - auc: 0.9550 - loss: 4.5544 - val_accuracy: 0.8307 - val_auc: 0.9785 - val_loss: 4.0495 - learning_rate: 1.0000e-04
# Epoch 10/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.7044 - auc: 0.9520 - loss: 4.2877 - val_accuracy: 0.8122 - val_auc: 0.9776 - val_loss: 3.8032 - learning_rate: 1.0000e-04
# Epoch 11/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.7352 - auc: 0.9589 - loss: 3.9604 - val_accuracy: 0.8095 - val_auc: 0.9785 - val_loss: 3.5529 - learning_rate: 1.0000e-04
# Epoch 12/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 30s 49ms/step - accuracy: 0.7414 - auc: 0.9588 - loss: 3.7220 - val_accuracy: 0.8108 - val_auc: 0.9800 - val_loss: 3.3216 - learning_rate: 1.0000e-04
# Epoch 13/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.7272 - auc: 0.9610 - loss: 3.4963 - val_accuracy: 0.8095 - val_auc: 0.9791 - val_loss: 3.1307 - learning_rate: 1.0000e-04
# Epoch 14/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 42ms/step - accuracy: 0.7601 - auc: 0.9677 - loss: 3.2458 - val_accuracy: 0.8201 - val_auc: 0.9797 - val_loss: 2.9401 - learning_rate: 1.0000e-04
# Epoch 15/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.7493 - auc: 0.9643 - loss: 3.1075 - val_accuracy: 0.8069 - val_auc: 0.9787 - val_loss: 2.8004 - learning_rate: 1.0000e-04
# Epoch 16/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.7588 - auc: 0.9669 - loss: 2.9255 - val_accuracy: 0.8175 - val_auc: 0.9834 - val_loss: 2.6051 - learning_rate: 1.0000e-04
# Epoch 17/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 142s 233ms/step - accuracy: 0.7574 - auc: 0.9663 - loss: 2.8037 - val_accuracy: 0.8333 - val_auc: 0.9829 - val_loss: 2.4816 - learning_rate: 1.0000e-04
# Epoch 18/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 188s 308ms/step - accuracy: 0.7681 - auc: 0.9716 - loss: 2.6290 - val_accuracy: 0.8320 - val_auc: 0.9844 - val_loss: 2.3545 - learning_rate: 1.0000e-04
# Epoch 19/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.7797 - auc: 0.9744 - loss: 2.4809 - val_accuracy: 0.8333 - val_auc: 0.9769 - val_loss: 2.3151 - learning_rate: 1.0000e-04
# Epoch 20/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.7842 - auc: 0.9716 - loss: 2.4029 - val_accuracy: 0.8333 - val_auc: 0.9842 - val_loss: 2.1565 - learning_rate: 1.0000e-04
# Epoch 21/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 42ms/step - accuracy: 0.7942 - auc: 0.9733 - loss: 2.2885 - val_accuracy: 0.8492 - val_auc: 0.9831 - val_loss: 2.0728 - learning_rate: 1.0000e-04
# Epoch 22/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 42ms/step - accuracy: 0.7980 - auc: 0.9744 - loss: 2.1951 - val_accuracy: 0.8426 - val_auc: 0.9829 - val_loss: 2.0043 - learning_rate: 1.0000e-04
# Epoch 23/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 42ms/step - accuracy: 0.7839 - auc: 0.9741 - loss: 2.1217 - val_accuracy: 0.8571 - val_auc: 0.9794 - val_loss: 1.9490 - learning_rate: 1.0000e-04
# Epoch 24/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.7771 - auc: 0.9730 - loss: 2.0624 - val_accuracy: 0.8307 - val_auc: 0.9781 - val_loss: 1.8948 - learning_rate: 1.0000e-04
# Epoch 25/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.8070 - auc: 0.9776 - loss: 1.9480 - val_accuracy: 0.8347 - val_auc: 0.9801 - val_loss: 1.8444 - learning_rate: 1.0000e-04
# Epoch 26/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 42ms/step - accuracy: 0.8040 - auc: 0.9776 - loss: 1.9051 - val_accuracy: 0.8505 - val_auc: 0.9840 - val_loss: 1.7401 - learning_rate: 1.0000e-04
# Epoch 27/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8262 - auc: 0.9799 - loss: 1.8046 - val_accuracy: 0.8267 - val_auc: 0.9773 - val_loss: 1.7448 - learning_rate: 1.0000e-04
# Epoch 28/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8121 - auc: 0.9769 - loss: 1.7986 - val_accuracy: 0.8347 - val_auc: 0.9845 - val_loss: 1.6414 - learning_rate: 1.0000e-04
# Epoch 29/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.8106 - auc: 0.9804 - loss: 1.7212 - val_accuracy: 0.8611 - val_auc: 0.9854 - val_loss: 1.5802 - learning_rate: 1.0000e-04
# Epoch 30/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8370 - auc: 0.9816 - loss: 1.6375 - val_accuracy: 0.8585 - val_auc: 0.9849 - val_loss: 1.5390 - learning_rate: 1.0000e-04
# Epoch 31/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 43ms/step - accuracy: 0.8122 - auc: 0.9781 - loss: 1.6477 - val_accuracy: 0.8571 - val_auc: 0.9823 - val_loss: 1.5193 - learning_rate: 1.0000e-04
# Epoch 32/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 43ms/step - accuracy: 0.8349 - auc: 0.9830 - loss: 1.5445 - val_accuracy: 0.8426 - val_auc: 0.9822 - val_loss: 1.5075 - learning_rate: 1.0000e-04
# Epoch 33/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 42ms/step - accuracy: 0.8272 - auc: 0.9807 - loss: 1.5447 - val_accuracy: 0.8571 - val_auc: 0.9871 - val_loss: 1.4145 - learning_rate: 1.0000e-04
# Epoch 34/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8136 - auc: 0.9799 - loss: 1.5208 - val_accuracy: 0.8492 - val_auc: 0.9828 - val_loss: 1.4253 - learning_rate: 1.0000e-04
# Epoch 35/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8469 - auc: 0.9830 - loss: 1.4420 - val_accuracy: 0.8598 - val_auc: 0.9843 - val_loss: 1.3737 - learning_rate: 1.0000e-04
# Epoch 36/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8328 - auc: 0.9817 - loss: 1.4375 - val_accuracy: 0.8638 - val_auc: 0.9844 - val_loss: 1.3483 - learning_rate: 1.0000e-04
# Epoch 37/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8244 - auc: 0.9813 - loss: 1.4256 - val_accuracy: 0.8505 - val_auc: 0.9826 - val_loss: 1.3464 - learning_rate: 1.0000e-04
# Epoch 38/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8394 - auc: 0.9825 - loss: 1.3779 - val_accuracy: 0.8479 - val_auc: 0.9852 - val_loss: 1.2980 - learning_rate: 1.0000e-04
# Epoch 39/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8172 - auc: 0.9800 - loss: 1.3938 - val_accuracy: 0.8677 - val_auc: 0.9822 - val_loss: 1.2940 - learning_rate: 1.0000e-04
# Epoch 40/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8184 - auc: 0.9817 - loss: 1.3474 - val_accuracy: 0.8571 - val_auc: 0.9839 - val_loss: 1.2552 - learning_rate: 1.0000e-04
# Epoch 41/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8313 - auc: 0.9818 - loss: 1.3251 - val_accuracy: 0.8571 - val_auc: 0.9857 - val_loss: 1.2465 - learning_rate: 1.0000e-04
# Epoch 42/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8460 - auc: 0.9842 - loss: 1.2661 - val_accuracy: 0.8413 - val_auc: 0.9815 - val_loss: 1.2782 - learning_rate: 1.0000e-04
# Epoch 43/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8118 - auc: 0.9796 - loss: 1.3249 - val_accuracy: 0.8532 - val_auc: 0.9818 - val_loss: 1.2177 - learning_rate: 1.0000e-04
# Epoch 44/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8471 - auc: 0.9855 - loss: 1.2232 - val_accuracy: 0.8611 - val_auc: 0.9847 - val_loss: 1.1926 - learning_rate: 1.0000e-04
# Epoch 45/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8357 - auc: 0.9864 - loss: 1.1945 - val_accuracy: 0.8519 - val_auc: 0.9837 - val_loss: 1.1885 - learning_rate: 1.0000e-04
# Epoch 46/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8235 - auc: 0.9807 - loss: 1.2491 - val_accuracy: 0.8651 - val_auc: 0.9874 - val_loss: 1.1279 - learning_rate: 1.0000e-04
# Epoch 47/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8308 - auc: 0.9837 - loss: 1.1954 - val_accuracy: 0.8466 - val_auc: 0.9866 - val_loss: 1.1347 - learning_rate: 1.0000e-04
# Epoch 48/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8446 - auc: 0.9850 - loss: 1.1694 - val_accuracy: 0.8492 - val_auc: 0.9815 - val_loss: 1.1688 - learning_rate: 1.0000e-04
# Epoch 49/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8400 - auc: 0.9859 - loss: 1.1479 - val_accuracy: 0.8571 - val_auc: 0.9850 - val_loss: 1.1176 - learning_rate: 1.0000e-04
# Epoch 50/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8486 - auc: 0.9845 - loss: 1.1450 - val_accuracy: 0.8413 - val_auc: 0.9818 - val_loss: 1.1544 - learning_rate: 1.0000e-04
# Epoch 51/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8398 - auc: 0.9830 - loss: 1.1613 - val_accuracy: 0.8479 - val_auc: 0.9799 - val_loss: 1.1506 - learning_rate: 1.0000e-04
# Epoch 52/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8482 - auc: 0.9835 - loss: 1.1211 - val_accuracy: 0.8347 - val_auc: 0.9810 - val_loss: 1.1430 - learning_rate: 1.0000e-04
# Epoch 53/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8508 - auc: 0.9873 - loss: 1.0643 - val_accuracy: 0.8492 - val_auc: 0.9857 - val_loss: 1.0690 - learning_rate: 1.0000e-04
# Epoch 54/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8429 - auc: 0.9834 - loss: 1.1107 - val_accuracy: 0.8466 - val_auc: 0.9808 - val_loss: 1.1166 - learning_rate: 1.0000e-04
# Epoch 55/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8396 - auc: 0.9834 - loss: 1.1101 - val_accuracy: 0.8399 - val_auc: 0.9803 - val_loss: 1.0924 - learning_rate: 1.0000e-04
# Epoch 56/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8303 - auc: 0.9813 - loss: 1.1248 - val_accuracy: 0.8413 - val_auc: 0.9833 - val_loss: 1.0654 - learning_rate: 1.0000e-04
# Epoch 57/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8496 - auc: 0.9832 - loss: 1.0819 - val_accuracy: 0.8452 - val_auc: 0.9806 - val_loss: 1.0980 - learning_rate: 1.0000e-04
# Epoch 58/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8526 - auc: 0.9872 - loss: 1.0284 - val_accuracy: 0.8399 - val_auc: 0.9794 - val_loss: 1.0824 - learning_rate: 1.0000e-04
# Epoch 59/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8469 - auc: 0.9865 - loss: 1.0303 - val_accuracy: 0.8347 - val_auc: 0.9785 - val_loss: 1.0899 - learning_rate: 1.0000e-04
# Epoch 60/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8574 - auc: 0.9859 - loss: 1.0193 - val_accuracy: 0.8585 - val_auc: 0.9842 - val_loss: 1.0228 - learning_rate: 1.0000e-04
# Epoch 61/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 43ms/step - accuracy: 0.8527 - auc: 0.9857 - loss: 1.0119 - val_accuracy: 0.8505 - val_auc: 0.9814 - val_loss: 1.0394 - learning_rate: 1.0000e-04
# Epoch 62/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 43ms/step - accuracy: 0.8440 - auc: 0.9822 - loss: 1.0615 - val_accuracy: 0.8505 - val_auc: 0.9850 - val_loss: 1.0109 - learning_rate: 1.0000e-04
# Epoch 63/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.
100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 28s 45ms/step - accuracy: 0.8589 - auc: 0.9865 - loss: 0.9082 - val_accuracy: 0.8704 - val_auc: 0.9823 - val_loss: 0.9430 - learning_rate: 1.0000e-04
# Epoch 81/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 43ms/step - accuracy: 0.8482 - auc: 0.9869 - loss: 0.9116 - val_accuracy: 0.8479 - val_auc: 0.9802 - val_loss: 0.9759 - learning_rate: 1.0000e-04
# Epoch 82/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 43ms/step - accuracy: 0.8949 - auc: 0.9922 - loss: 0.8097 - val_accuracy: 0.8558 - val_auc: 0.9837 - val_loss: 0.9331 - learning_rate: 1.0000e-04
# Epoch 83/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 43ms/step - accuracy: 0.8598 - auc: 0.9883 - loss: 0.8680 - val_accuracy: 0.8426 - val_auc: 0.9794 - val_loss: 0.9582 - learning_rate: 1.0000e-04
# Epoch 84/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 43ms/step - accuracy: 0.8615 - auc: 0.9873 - loss: 0.8928 - val_accuracy: 0.8505 - val_auc: 0.9808 - val_loss: 0.9572 - learning_rate: 1.0000e-04
# Epoch 85/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.8615 - auc: 0.9891 - loss: 0.8559 - val_accuracy: 0.8492 - val_auc: 0.9788 - val_loss: 0.9938 - learning_rate: 1.0000e-04
# Epoch 86/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.8684 - auc: 0.9891 - loss: 0.8598 - val_accuracy: 0.8360 - val_auc: 0.9804 - val_loss: 0.9830 - learning_rate: 1.0000e-04
# Epoch 87/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8623 - auc: 0.9858 - loss: 0.8970 - val_accuracy: 0.8598 - val_auc: 0.9788 - val_loss: 0.9462 - learning_rate: 1.0000e-04
# Epoch 88/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8554 - auc: 0.9850 - loss: 0.9154 - val_accuracy: 0.8214 - val_auc: 0.9766 - val_loss: 1.0037 - learning_rate: 1.0000e-04
# Epoch 89/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8737 - auc: 0.9885 - loss: 0.8603 - val_accuracy: 0.8386 - val_auc: 0.9823 - val_loss: 0.9288 - learning_rate: 1.0000e-04
# Epoch 90/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8672 - auc: 0.9875 - loss: 0.8702 - val_accuracy: 0.8519 - val_auc: 0.9813 - val_loss: 0.9327 - learning_rate: 1.0000e-04
# Epoch 91/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8529 - auc: 0.9850 - loss: 0.9050 - val_accuracy: 0.8558 - val_auc: 0.9808 - val_loss: 0.9368 - learning_rate: 1.0000e-04
# Epoch 92/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8632 - auc: 0.9872 - loss: 0.8733 - val_accuracy: 0.8532 - val_auc: 0.9832 - val_loss: 0.8940 - learning_rate: 1.0000e-04
# Epoch 93/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8482 - auc: 0.9869 - loss: 0.8831 - val_accuracy: 0.8505 - val_auc: 0.9842 - val_loss: 0.9097 - learning_rate: 1.0000e-04
# Epoch 94/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8574 - auc: 0.9864 - loss: 0.8909 - val_accuracy: 0.8532 - val_auc: 0.9823 - val_loss: 0.9237 - learning_rate: 1.0000e-04
# Epoch 95/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8611 - auc: 0.9883 - loss: 0.8516 - val_accuracy: 0.8598 - val_auc: 0.9818 - val_loss: 0.9141 - learning_rate: 1.0000e-04
# Epoch 96/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8679 - auc: 0.9864 - loss: 0.8625 - val_accuracy: 0.8664 - val_auc: 0.9799 - val_loss: 0.9224 - learning_rate: 1.0000e-04
# Epoch 97/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8535 - auc: 0.9874 - loss: 0.8608 - val_accuracy: 0.8770 - val_auc: 0.9862 - val_loss: 0.8615 - learning_rate: 1.0000e-04
# Epoch 98/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8749 - auc: 0.9895 - loss: 0.8259 - val_accuracy: 0.8426 - val_auc: 0.9825 - val_loss: 0.9166 - learning_rate: 1.0000e-04
# Epoch 99/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8720 - auc: 0.9862 - loss: 0.8482 - val_accuracy: 0.8505 - val_auc: 0.9810 - val_loss: 0.9404 - learning_rate: 1.0000e-04
# Epoch 100/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8629 - auc: 0.9863 - loss: 0.8579 - val_accuracy: 0.8320 - val_auc: 0.9831 - val_loss: 0.9389 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 97.

# %%
model.save("resnet50_model_final.keras")

# %%
# Convert history to DataFrame 
stats_df = pd.DataFrame(history.history)

#  Extract arrays 
train_losses = stats_df['loss'].to_numpy()
val_losses   = stats_df['val_loss'].to_numpy()
train_accs   = stats_df['accuracy'].to_numpy()
val_accs     = stats_df['val_accuracy'].to_numpy()

# NEW: extract AUC metrics
train_aucs = stats_df['auc'].to_numpy()
val_aucs   = stats_df['val_auc'].to_numpy()

#Epoch index & best epoch 
epochs_list   = np.arange(1, train_losses.size + 1)
best_epoch_ix = int(val_losses.argmin()) + 1

# Loss plot 
plt.figure()
plt.plot(epochs_list, train_losses, label='Training Loss')
plt.plot(epochs_list, val_losses,   label='Validation Loss')
plt.axvline(best_epoch_ix, linestyle='--', label=f'Best Epoch: {best_epoch_ix}')
plt.title('Training vs. Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

#Accuracy plot 
plt.figure()
plt.plot(epochs_list, train_accs, label='Training Accuracy')
plt.plot(epochs_list, val_accs,   label='Validation Accuracy')
plt.axvline(best_epoch_ix, linestyle='--', label=f'Best Epoch: {best_epoch_ix}')
plt.title('Training vs. Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

#AUC plot 
plt.figure()
plt.plot(epochs_list, train_aucs, label='Training AUC')
plt.plot(epochs_list, val_aucs,   label='Validation AUC')
plt.axvline(best_epoch_ix, linestyle='--', label=f'Best Epoch: {best_epoch_ix}')
plt.title('Training vs. Validation AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report, roc_auc_score
import tensorflow as tf
import pandas as pd
import numpy as np

# Data loader for test set 
test_root = Path("../data/WasteSplit") / "test"
test_only_gen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet50.preprocess_input
).flow_from_directory(
    directory=str(test_root),
    target_size=(H, W),        # Fixed
    batch_size=BATCH,          # Fixed
    class_mode="categorical",
    shuffle=False
)

# Predictions & classification report 
probs_test   = model.predict(test_only_gen, verbose=0)  # Fixed
pred_indices = np.argmax(probs_test, axis=1)
true_indices = test_only_gen.classes

raw_labels    = list(test_only_gen.class_indices.keys())
pretty_labels = [f"{i+1}-{lbl}" for i, lbl in enumerate(raw_labels)]

report_map = classification_report(
    true_indices,
    pred_indices,
    target_names=pretty_labels,
    output_dict=True
)

report_df = pd.DataFrame(report_map).T.round(2)
summaries   = ['accuracy', 'macro avg', 'weighted avg']
class_order = [r for r in report_df.index if r not in summaries]
report_df   = report_df.loc[class_order + summaries]

print("\nResNet50 Test‑Set Classification Report:\n")
print(report_df.to_string())

# Compute & print Macro‑AUC 
y_true_oh = tf.keras.utils.to_categorical(true_indices, num_classes=test_only_gen.num_classes)
macro_auc = roc_auc_score(y_true_oh, probs_test, average='macro', multi_class='ovo')
print(f"\nMacro‑average ROC‑AUC: {macro_auc:.2f}")
# Out:
# Found 954 images belonging to 9 classes.
#
# ResNet50 Test‑Set Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.74    0.91      0.82    93.00
# 2-2-Food Organics             0.91    0.73      0.81    83.00
# 3-3-Glass                     0.87    0.70      0.78    84.00
# 4-4-Metal                     0.67    0.92      0.78   158.00
# 5-5-Miscellaneous Trash       0.70    0.31      0.43    99.00
# 6-6-Paper                     0.84    0.91      0.88   100.00
# 7-7-Plastic                   0.83    0.78      0.80   185.00
# 8-8-Textile Trash             0.81    0.72      0.76    64.00
# 9-9-Vegetation                0.80    0.98      0.88    88.00
# accuracy                      0.78    0.78      0.78     0.78
# macro avg                     0.80    0.77      0.77   954.00
# weighted avg                  0.79    0.78      0.77   954.00
#
# Macro‑average ROC‑AUC: 0.97

# %%
from sklearn.metrics import (
    classification_report,
    roc_auc_score,
    f1_score,
    precision_score,
    recall_score
)

def evaluate_and_report(model, generator, set_name):
    print(f"\nEvaluating {set_name} set...")

    # Predict probabilities & hard labels
    probs = model.predict(generator, verbose=0)
    preds = np.argmax(probs, axis=1)
    trues = generator.classes

    raw_labels    = list(generator.class_indices.keys())
    pretty_labels = [f"{i+1}-{lbl}" for i, lbl in enumerate(raw_labels)]

    # Per‑class precision/recall/f1
    rep_dict = classification_report(
        trues, preds,
        target_names=pretty_labels,
        output_dict=True
    )
    rep_df = pd.DataFrame(rep_dict).T.round(2)
    summaries    = ['accuracy', 'macro avg', 'weighted avg']
    class_order  = [r for r in rep_df.index if r not in summaries]
    rep_df       = rep_df.loc[class_order + summaries]

    print(f"\n{set_name} Classification Report:\n")
    print(rep_df.to_string())

    # Macro‑average ROC‑AUC
    y_true_oh = tf.keras.utils.to_categorical(trues, num_classes=generator.num_classes)
    macro_auc = roc_auc_score(y_true_oh, probs, average='macro', multi_class='ovo')

    # Macro‑average precision/recall/f1
    macro_prec = precision_score(trues, preds, average='macro')
    macro_rec  = recall_score(trues, preds, average='macro')
    macro_f1   = f1_score(trues, preds, average='macro')

    print(f"\n{set_name} Summary Metrics:")
    print(f"  Precision: {macro_prec:.4f}")
    print(f"  Recall:    {macro_rec:.4f}")
    print(f"  F1 Score:  {macro_f1:.4f}")
    print(f"  AUC:       {macro_auc:.4f}\n")

    return rep_df

train_report_df = evaluate_and_report(model,            train_stream,      "Train")
val_report_df   = evaluate_and_report(model,            validation_stream, "Validation")
test_report_df  = evaluate_and_report(model,            test_only_gen,     "Test")
# Out:
# Evaluating Train set...
#
# Train Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.08    0.08      0.08   295.00
# 2-2-Food Organics             0.09    0.09      0.09   263.00
# 3-3-Glass                     0.09    0.09      0.09   269.00
# 4-4-Metal                     0.15    0.15      0.15   506.00
# 5-5-Miscellaneous Trash       0.05    0.05      0.05   317.00
# 6-6-Paper                     0.09    0.09      0.09   320.00
# 7-7-Plastic                   0.17    0.17      0.17   589.00
# 8-8-Textile Trash             0.08    0.08      0.08   204.00
# 9-9-Vegetation                0.10    0.10      0.10   279.00
# accuracy                      0.11    0.11      0.11     0.11
# macro avg                     0.10    0.10      0.10  3042.00
# weighted avg                  0.11    0.11      0.11  3042.00
#
# Train Summary Metrics:
#   Precision: 0.1010
#   Recall:    0.1011
#   F1 Score:  0.1010
#   AUC:       0.4922
#
#
# Evaluating Validation set...
#
# Validation Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.78    0.86      0.82    73.00
# 2-2-Food Organics             0.91    0.82      0.86    65.00
# 3-3-Glass                     0.92    0.90      0.91    67.00
# 4-4-Metal                     0.93    0.85      0.89   126.00
# 5-5-Miscellaneous Trash       0.85    0.80      0.82    79.00
# 6-6-Paper                     0.91    0.89      0.90    80.00
# 7-7-Plastic                   0.78    0.84      0.81   147.00
# 8-8-Textile Trash             0.86    0.84      0.85    50.00
# 9-9-Vegetation                0.86    0.97      0.91    69.00
# accuracy                      0.86    0.86      0.86     0.86
# macro avg                     0.87    0.86      0.86   756.00
# weighted avg                  0.86    0.86      0.86   756.00
#
# Validation Summary Metrics:
#   Precision: 0.8675
#   Recall:    0.8625
#   F1 Score:  0.8636
#   AUC:       0.9852
#
#
# Evaluating Test set...
#
# Test Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.74    0.91      0.82    93.00
# 2-2-Food Organics             0.91    0.73      0.81    83.00
# 3-3-Glass                     0.87    0.70      0.78    84.00
# 4-4-Metal                     0.67    0.92      0.78   158.00
# 5-5-Miscellaneous Trash       0.70    0.31      0.43    99.00
# 6-6-Paper                     0.84    0.91      0.88   100.00
# 7-7-Plastic                   0.83    0.78      0.80   185.00
# 8-8-Textile Trash             0.81    0.72      0.76    64.00
# 9-9-Vegetation                0.80    0.98      0.88    88.00
# accuracy                      0.78    0.78      0.78     0.78
# macro avg                     0.80    0.77      0.77   954.00
# weighted avg                  0.79    0.78      0.77   954.00
#
# Test Summary Metrics:
#   Precision: 0.7980
#   Recall:    0.7741
#   F1 Score:  0.7711
#   AUC:       0.9680

# %% [markdown]
# - - -

# %% [markdown]
# # Next Model - Resnet101.

# %%
'''
DATA_DIR = Path("../data/WasteSplit")
IMG_DIMS = (224, 224)
BATCH_SZ = 5
EPOCHS   = 1

augmented_preprocessor = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet.preprocess_input,
    rotation_range=15,             # small random rotations
    width_shift_range=0.15,        # horizontal shifts
    height_shift_range=0.15,       # vertical shifts
    zoom_range=0.15,               # random zoom
    shear_range=0.1,               # slight shearing
    brightness_range=(0.9, 1.1),   # slight brightness variation
    horizontal_flip=True           # random flips
)

def make_generator(
    subset_name: str,
    shuffle_data: bool = False
) -> tf.keras.preprocessing.image.DirectoryIterator:
    """
    Creates a DirectoryIterator for the given subset ('train', 'val', or 'test').
    """
    return augmented_preprocessor.flow_from_directory(
        directory=str(DATA_DIR / subset_name),
        target_size=IMG_DIMS,
        batch_size=BATCH_SZ,
        class_mode="categorical",
        shuffle=shuffle_data
    )

generators: Dict[str, tf.keras.preprocessing.image.DirectoryIterator] = {
    split: make_generator(split, shuffle_data=(split == "train"))
    for split in ("train", "val", "test")
}

train_loader = generators["train"]
val_loader   = generators["val"]
test_loader  = generators["test"]
'''

from pathlib import Path
from typing import Dict
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.metrics import AUC

DATA_DIR   = Path("../data/WasteSplit")
IMG_DIMS   = (224, 224)
BATCH_SZ   = 5
EPOCHS     = 100

# ─── Augmented preprocessor
augmented_preprocessor = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.resnet.preprocess_input,
    rotation_range=15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    zoom_range=0.15,
    shear_range=0.1,
    brightness_range=(0.9, 1.1),
    horizontal_flip=True
)

# ─── Generator factory 
def make_generator(
    subset_name: str,
    shuffle_data: bool = False
) -> tf.keras.preprocessing.image.DirectoryIterator:
    """
    Creates a DirectoryIterator for 'train', 'val', or 'test'.
    """
    return augmented_preprocessor.flow_from_directory(
        directory=str(DATA_DIR / subset_name),
        target_size=IMG_DIMS,
        batch_size=BATCH_SZ,
        class_mode="categorical",
        shuffle=shuffle_data
    )

generators: Dict[str, tf.keras.preprocessing.image.DirectoryIterator] = {
    split: make_generator(split, shuffle_data=(split == "train"))
    for split in ("train", "val", "test")
}

train_loader = generators["train"]
val_loader   = generators["val"]
test_loader  = generators["test"]

# Later, when you compile your model 
from tensorflow.keras.optimizers import Adam

# assume `model` is your built Keras model:
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy", AUC(name="auc")]
)

history = model.fit(
    train_loader,
    validation_data=val_loader,
    epochs=EPOCHS,
    callbacks=[],
    verbose=1
)
# Out:
# Found 3042 images belonging to 9 classes.
# Found 756 images belonging to 9 classes.
# Found 954 images belonging to 9 classes.
# Epoch 1/100
# /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 30s 44ms/step - accuracy: 0.8717 - auc: 0.9898 - loss: 0.8053 - val_accuracy: 0.8558 - val_auc: 0.9819 - val_loss: 0.9219
# Epoch 2/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8820 - auc: 0.9911 - loss: 0.7960 - val_accuracy: 0.8743 - val_auc: 0.9834 - val_loss: 0.8895
# Epoch 3/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8883 - auc: 0.9904 - loss: 0.7788 - val_accuracy: 0.8532 - val_auc: 0.9805 - val_loss: 0.8986
# Epoch 4/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8711 - auc: 0.9890 - loss: 0.8131 - val_accuracy: 0.8677 - val_auc: 0.9837 - val_loss: 0.8502
# Epoch 5/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.8860 - auc: 0.9879 - loss: 0.7984 - val_accuracy: 0.8717 - val_auc: 0.9810 - val_loss: 0.8912
# Epoch 6/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.8815 - auc: 0.9894 - loss: 0.7956 - val_accuracy: 0.8690 - val_auc: 0.9792 - val_loss: 0.9273
# Epoch 7/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.8792 - auc: 0.9877 - loss: 0.8121 - val_accuracy: 0.8611 - val_auc: 0.9810 - val_loss: 0.8839
# Epoch 8/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.8804 - auc: 0.9902 - loss: 0.7999 - val_accuracy: 0.8545 - val_auc: 0.9855 - val_loss: 0.8702
# Epoch 9/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8763 - auc: 0.9905 - loss: 0.7947 - val_accuracy: 0.8611 - val_auc: 0.9848 - val_loss: 0.8754
# Epoch 10/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 41ms/step - accuracy: 0.8900 - auc: 0.9904 - loss: 0.7832 - val_accuracy: 0.8638 - val_auc: 0.9863 - val_loss: 0.8352
# Epoch 11/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.9002 - auc: 0.9930 - loss: 0.7262 - val_accuracy: 0.8664 - val_auc: 0.9828 - val_loss: 0.8504
# Epoch 12/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8763 - auc: 0.9888 - loss: 0.8063 - val_accuracy: 0.8598 - val_auc: 0.9868 - val_loss: 0.8484
# Epoch 13/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8801 - auc: 0.9899 - loss: 0.7789 - val_accuracy: 0.8624 - val_auc: 0.9854 - val_loss: 0.8351
# Epoch 14/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8984 - auc: 0.9920 - loss: 0.7355 - val_accuracy: 0.8545 - val_auc: 0.9847 - val_loss: 0.8598
# Epoch 15/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.
100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8931 - auc: 0.9918 - loss: 0.7126 - val_accuracy: 0.8651 - val_auc: 0.9840 - val_loss: 0.8307
# Epoch 82/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.9048 - auc: 0.9926 - loss: 0.6919 - val_accuracy: 0.8519 - val_auc: 0.9777 - val_loss: 0.9128
# Epoch 83/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8980 - auc: 0.9929 - loss: 0.6881 - val_accuracy: 0.8545 - val_auc: 0.9833 - val_loss: 0.8400
# Epoch 84/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.9003 - auc: 0.9936 - loss: 0.6780 - val_accuracy: 0.8664 - val_auc: 0.9853 - val_loss: 0.8109
# Epoch 85/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8805 - auc: 0.9889 - loss: 0.7473 - val_accuracy: 0.8532 - val_auc: 0.9814 - val_loss: 0.8723
# Epoch 86/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8968 - auc: 0.9893 - loss: 0.7286 - val_accuracy: 0.8611 - val_auc: 0.9831 - val_loss: 0.8314
# Epoch 87/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8958 - auc: 0.9923 - loss: 0.7032 - val_accuracy: 0.8717 - val_auc: 0.9831 - val_loss: 0.8254
# Epoch 88/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8736 - auc: 0.9910 - loss: 0.7425 - val_accuracy: 0.8638 - val_auc: 0.9824 - val_loss: 0.8481
# Epoch 89/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.9052 - auc: 0.9936 - loss: 0.6730 - val_accuracy: 0.8638 - val_auc: 0.9823 - val_loss: 0.8412
# Epoch 90/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8958 - auc: 0.9904 - loss: 0.7151 - val_accuracy: 0.8690 - val_auc: 0.9828 - val_loss: 0.8094
# Epoch 91/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8939 - auc: 0.9908 - loss: 0.7148 - val_accuracy: 0.8743 - val_auc: 0.9792 - val_loss: 0.8364
# Epoch 92/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8836 - auc: 0.9913 - loss: 0.7158 - val_accuracy: 0.8690 - val_auc: 0.9846 - val_loss: 0.8281
# Epoch 93/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.9067 - auc: 0.9935 - loss: 0.6640 - val_accuracy: 0.8638 - val_auc: 0.9853 - val_loss: 0.7826
# Epoch 94/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.9004 - auc: 0.9913 - loss: 0.6950 - val_accuracy: 0.8717 - val_auc: 0.9827 - val_loss: 0.8282
# Epoch 95/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8899 - auc: 0.9901 - loss: 0.7339 - val_accuracy: 0.8598 - val_auc: 0.9822 - val_loss: 0.8540
# Epoch 96/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8909 - auc: 0.9908 - loss: 0.7138 - val_accuracy: 0.8360 - val_auc: 0.9807 - val_loss: 0.8598
# Epoch 97/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8922 - auc: 0.9919 - loss: 0.6998 - val_accuracy: 0.8704 - val_auc: 0.9844 - val_loss: 0.8027
# Epoch 98/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8901 - auc: 0.9902 - loss: 0.7230 - val_accuracy: 0.8571 - val_auc: 0.9792 - val_loss: 0.8723
# Epoch 99/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - accuracy: 0.8988 - auc: 0.9941 - loss: 0.6647 - val_accuracy: 0.8558 - val_auc: 0.9846 - val_loss: 0.8275
# Epoch 100/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 25s 40ms/step - accuracy: 0.8868 - auc: 0.9912 - loss: 0.7175 - val_accuracy: 0.8585 - val_auc: 0.9845 - val_loss: 0.8436

# %%
#training History into a DataFrame
resnet101_history_df = pd.DataFrame(history.history)

#1‑based epoch index
epochs = np.arange(1, resnet101_history_df.shape[0] + 1)

#which epoch had the lowest validation loss
best_epoch = int(resnet101_history_df['val_loss'].idxmin()) + 1

#Loss Plot
plt.figure()
plt.plot(epochs, resnet101_history_df['loss'],      label='Training Loss')
plt.plot(epochs, resnet101_history_df['val_loss'],  label='Validation Loss')
plt.axvline(best_epoch, linestyle='--',             label=f'Best Epoch: {best_epoch}')
plt.title('ResNet101 Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

#Accuracy Plot
plt.figure()
plt.plot(epochs, resnet101_history_df['accuracy'],     label='Training Accuracy')
plt.plot(epochs, resnet101_history_df['val_accuracy'], label='Validation Accuracy')
plt.axvline(best_epoch, linestyle='--',                label=f'Best Epoch: {best_epoch}')
plt.title('ResNet101 Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Extract AUC values
train_aucs = resnet101_history_df['auc'].to_numpy()
val_aucs   = resnet101_history_df['val_auc'].to_numpy()

# Plot AUC Curve
plt.figure()
plt.plot(epochs, train_aucs, label='Training AUC')
plt.plot(epochs, val_aucs,   label='Validation AUC')
plt.axvline(best_epoch, linestyle='--', label=f'Best Epoch: {best_epoch}')
plt.title('ResNet101 AUC Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report, roc_auc_score, f1_score, precision_score, recall_score

def evaluate_and_report(model, generator, set_name):
    print(f"\nEvaluating {set_name} set...")
    probs = model.predict(generator, verbose=0)
    preds = np.argmax(probs, axis=1)
    trues = generator.classes

    raw_labels = list(generator.class_indices.keys())
    pretty_labels = [f"{i+1}-{lbl}" for i, lbl in enumerate(raw_labels)]

    # Classification Report
    report = classification_report(trues, preds, target_names=pretty_labels, output_dict=True)
    report_df = pd.DataFrame(report).T.round(2)

    summary_keys = ['accuracy', 'macro avg', 'weighted avg']
    class_keys = [r for r in report_df.index if r not in summary_keys]
    report_df = report_df.loc[class_keys + summary_keys]

    print(f"\nResNet101 {set_name} Classification Report:\n")
    print(report_df.to_string())

    # AUC, F1, Precision, Recall
    y_true_oh = tf.keras.utils.to_categorical(trues, num_classes=generator.num_classes)
    macro_auc = roc_auc_score(y_true_oh, probs, average='macro', multi_class='ovo')
    f1 = f1_score(trues, preds, average='macro')
    precision = precision_score(trues, preds, average='macro')
    recall = recall_score(trues, preds, average='macro')

    print(f"\nResNet101 Model {set_name} Metrics:")
    print(f"F1 Score: {f1:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"AUC: {macro_auc:.4f}\n")

    return report_df

# ─── Evaluate All Sets
train_report_df = evaluate_and_report(model, train_loader, "Train")
val_report_df   = evaluate_and_report(model, val_loader, "Validation")
test_report_df  = evaluate_and_report(model, test_loader, "Test")
# Out:
# Evaluating Train set...
#
# ResNet101 Train Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.12    0.12      0.12   295.00
# 2-2-Food Organics             0.08    0.08      0.08   263.00
# 3-3-Glass                     0.10    0.09      0.09   269.00
# 4-4-Metal                     0.19    0.19      0.19   506.00
# 5-5-Miscellaneous Trash       0.10    0.10      0.10   317.00
# 6-6-Paper                     0.12    0.12      0.12   320.00
# 7-7-Plastic                   0.19    0.19      0.19   589.00
# 8-8-Textile Trash             0.08    0.08      0.08   204.00
# 9-9-Vegetation                0.09    0.09      0.09   279.00
# accuracy                      0.13    0.13      0.13     0.13
# macro avg                     0.12    0.12      0.12  3042.00
# weighted avg                  0.13    0.13      0.13  3042.00
#
# ResNet101 Model Train Metrics:
# F1 Score: 0.1184
# Precision: 0.1184
# Recall: 0.1185
# AUC: 0.5038
#
#
# Evaluating Validation set...
#
# ResNet101 Validation Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.85    0.85      0.85    73.00
# 2-2-Food Organics             0.85    0.95      0.90    65.00
# 3-3-Glass                     0.94    0.87      0.90    67.00
# 4-4-Metal                     0.85    0.92      0.89   126.00
# 5-5-Miscellaneous Trash       0.82    0.75      0.78    79.00
# 6-6-Paper                     0.93    0.94      0.93    80.00
# 7-7-Plastic                   0.88    0.82      0.85   147.00
# 8-8-Textile Trash             0.83    0.90      0.87    50.00
# 9-9-Vegetation                0.94    0.93      0.93    69.00
# accuracy                      0.87    0.87      0.87     0.87
# macro avg                     0.88    0.88      0.88   756.00
# weighted avg                  0.88    0.87      0.87   756.00
#
# ResNet101 Model Validation Metrics:
# F1 Score: 0.8767
# Precision: 0.8759
# Recall: 0.8797
# AUC: 0.9865
#
#
# Evaluating Test set...
# /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# ResNet101 Test Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.84    0.83      0.83    93.00
# 2-2-Food Organics             0.81    0.89      0.85    83.00
# 3-3-Glass                     0.93    0.62      0.74    84.00
# 4-4-Metal                     0.76    0.88      0.82   158.00
# 5-5-Miscellaneous Trash       0.74    0.57      0.64    99.00
# 6-6-Paper                     0.89    0.95      0.92   100.00
# 7-7-Plastic                   0.74    0.88      0.80   185.00
# 8-8-Textile Trash             0.80    0.69      0.74    64.00
# 9-9-Vegetation                0.99    0.85      0.91    88.00
# accuracy                      0.81    0.81      0.81     0.81
# macro avg                     0.83    0.79      0.81   954.00
# weighted avg                  0.82    0.81      0.81   954.00
#
# ResNet101 Model Test Metrics:
# F1 Score: 0.8064
# Precision: 0.8326
# Recall: 0.7944
# AUC: 0.9724

# %%
resnet101_model = model
resnet101_model.save("Resnet101_model_final.keras")

# %% [markdown]
# - - -

# %% [markdown]
# # Next Model - VGG16. #

# %%
DATA_DIR: Path        = Path("../data/WasteSplit")
IMAGE_DIMS: Tuple[int,int] = (224, 224)
BATCH_SZ: int         = 5
EPOCHS: int           = 100

#VGG16‑Style Augmentation & Preprocessing
vgg_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.vgg16.preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    brightness_range=(0.8, 1.2),
    horizontal_flip=True
)

def create_vgg_iterator(
    split: str,
    shuffle: bool = False
) -> tf.keras.preprocessing.image.DirectoryIterator:
    """
    Returns a DirectoryIterator for one of ['train','val','test'] subsets.
    """
    split_path = DATA_DIR / split
    return vgg_generator.flow_from_directory(
        directory=str(split_path),
        target_size=IMAGE_DIMS,
        batch_size=BATCH_SZ,
        class_mode="categorical",
        shuffle=shuffle
    )

vgg_train_iter = create_vgg_iterator("train", shuffle=True)
vgg_val_iter   = create_vgg_iterator("val",   shuffle=False)
vgg_test_iter  = create_vgg_iterator("test",  shuffle=False)
# Out:
# Found 3042 images belonging to 9 classes.
# Found 756 images belonging to 9 classes.
# Found 954 images belonging to 9 classes.

# %%
'''
#Load & freeze the VGG16 backbone
vgg_core = VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(*IMAGE_DIMS, 3),
    name="vgg16_core"
)
vgg_core.trainable = False

#Shared L2 penalty and Dense→BN→ReLU helper
l2_penalty = l2(1e-2)
def dense_block(x, units, tag):
    x = Dense(units, kernel_regularizer=l2_penalty, name=f"{tag}_dense")(x)
    x = BatchNormalization(name=f"{tag}_bn")(x)
    return Activation("relu", name=f"{tag}_act")(x)

#classification head
x = GlobalAveragePooling2D(name="vgg_gap")(vgg_core.output)
x = dense_block(x, 256, "vgg_blk1")
x = dense_block(x, 128, "vgg_blk2")
x = Dropout(0.2, name="vgg_dropout")(x)
x = dense_block(x, 64,  "vgg_blk3")

preds = Dense(
    vgg_train_iter.num_classes,
    activation="softmax",
    name="vgg_output"
)(x)

#Assemble & compile the model
vgg_model = Model(inputs=vgg_core.input, outputs=preds, name="WasteSplit_VGG16")
vgg_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

#Train with EarlyStopping
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=40,
    restore_best_weights=True,
    verbose=1
)

vgg_history = vgg_model.fit(
    vgg_train_iter,
    validation_data=vgg_val_iter,
    epochs=EPOCHS,
    callbacks=[early_stop],
    verbose=2
)
'''
from tensorflow.keras.metrics import AUC

# ─── Load & freeze the VGG16 backbone 
vgg_core = VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(*IMAGE_DIMS, 3),
    name="vgg16_core"
)
vgg_core.trainable = False

# ─── Shared L2 penalty and Dense→BN→ReLU helper 
l2_penalty = l2(1e-2)
def dense_block(x, units, tag):
    x = Dense(units, kernel_regularizer=l2_penalty, name=f"{tag}_dense")(x)
    x = BatchNormalization(name=f"{tag}_bn")(x)
    return Activation("relu", name=f"{tag}_act")(x)

# ─── Classification head 
x = GlobalAveragePooling2D(name="vgg_gap")(vgg_core.output)
x = dense_block(x, 256, "vgg_blk1")
x = dense_block(x, 128, "vgg_blk2")
x = Dropout(0.2, name="vgg_dropout")(x)
x = dense_block(x, 64,  "vgg_blk3")

preds = Dense(
    vgg_train_iter.num_classes,
    activation="softmax",
    name="vgg_output"
)(x)

# ─── Assemble & compile the model (with AUC) 
vgg_model = Model(inputs=vgg_core.input, outputs=preds, name="WasteSplit_VGG16")
vgg_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy", AUC(name="auc")]
)

# ─── Train with EarlyStopping 
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=40,
    restore_best_weights=True,
    verbose=1
)

vgg_history = vgg_model.fit(
    vgg_train_iter,
    validation_data=vgg_val_iter,
    epochs=EPOCHS,
    callbacks=[early_stop],
    verbose=2
)
# Out:
# Epoch 1/100
# /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 609/609 - 27s - 44ms/step - accuracy: 0.2235 - auc: 0.6526 - loss: 7.8664 - val_accuracy: 0.4206 - val_auc: 0.8054 - val_loss: 7.2729
# Epoch 2/100
# 609/609 - 24s - 39ms/step - accuracy: 0.3675 - auc: 0.7912 - loss: 7.1426 - val_accuracy: 0.5119 - val_auc: 0.8707 - val_loss: 6.6569
# Epoch 3/100
# 609/609 - 24s - 40ms/step - accuracy: 0.4168 - auc: 0.8368 - loss: 6.6293 - val_accuracy: 0.5873 - val_auc: 0.9053 - val_loss: 6.1186
# Epoch 4/100
# 609/609 - 25s - 41ms/step - accuracy: 0.4747 - auc: 0.8648 - loss: 6.1633 - val_accuracy: 0.6151 - val_auc: 0.9199 - val_loss: 5.6930
# Epoch 5/100
# 609/609 - 25s - 41ms/step - accuracy: 0.5329 - auc: 0.8832 - loss: 5.7499 - val_accuracy: 0.6455 - val_auc: 0.9273 - val_loss: 5.3059
100
# 609/609 - 28s - 46ms/step - accuracy: 0.8225 - auc: 0.9810 - loss: 0.9079 - val_accuracy: 0.8161 - val_auc: 0.9766 - val_loss: 0.9353
# Epoch 97/100
# 609/609 - 28s - 46ms/step - accuracy: 0.8281 - auc: 0.9800 - loss: 0.9057 - val_accuracy: 0.8201 - val_auc: 0.9758 - val_loss: 0.9352
# Epoch 98/100
# 609/609 - 28s - 46ms/step - accuracy: 0.8268 - auc: 0.9812 - loss: 0.8958 - val_accuracy: 0.8280 - val_auc: 0.9750 - val_loss: 0.9573
# Epoch 99/100
# 609/609 - 28s - 46ms/step - accuracy: 0.8343 - auc: 0.9809 - loss: 0.8903 - val_accuracy: 0.7910 - val_auc: 0.9773 - val_loss: 0.9503
# Epoch 100/100
# 609/609 - 28s - 47ms/step - accuracy: 0.8297 - auc: 0.9805 - loss: 0.9089 - val_accuracy: 0.8003 - val_auc: 0.9701 - val_loss: 0.9985
# Restoring model weights from the end of the best epoch: 91.

# %%
vgg16_model = model
vgg16_model.save('vgg16_model_final.keras')

# %%
# VGG16 training history into a DataFrame
vgg_history_df = pd.DataFrame(vgg_history.history)

epoch_indices = np.arange(1, vgg_history_df.shape[0] + 1)

# epoch with the lowest validation loss
optimal_epoch = int(vgg_history_df['val_loss'].idxmin()) + 1

# ─── Loss Curve 
plt.figure()
plt.plot(epoch_indices, vgg_history_df['loss'],      label='Train Loss')
plt.plot(epoch_indices, vgg_history_df['val_loss'],  label='Val Loss')
plt.axvline(optimal_epoch, linestyle='--',           label=f'Best Epoch: {optimal_epoch}')
plt.title('VGG16 Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# ─── Accuracy Curve 
plt.figure()
plt.plot(epoch_indices, vgg_history_df['accuracy'],     label='Train Accuracy')
plt.plot(epoch_indices, vgg_history_df['val_accuracy'], label='Val Accuracy')
plt.axvline(optimal_epoch, linestyle='--',              label=f'Best Epoch: {optimal_epoch}')
plt.title('VGG16 Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# ─── AUC Curve 
train_aucs = vgg_history_df['auc'].to_numpy()
val_aucs   = vgg_history_df['val_auc'].to_numpy()

plt.figure()
plt.plot(epoch_indices, train_aucs, label='Train AUC')
plt.plot(epoch_indices, val_aucs,   label='Val AUC')
plt.axvline(optimal_epoch, linestyle='--',             label=f'Best Epoch: {optimal_epoch}')
plt.title('VGG16 AUC Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()
plt.show()

# %%
def evaluate_and_report_vgg(model, generator, set_name):
    print(f"\nEvaluating {set_name} set...")
    probs = model.predict(generator, verbose=0)
    preds = np.argmax(probs, axis=1)
    trues = generator.classes

    raw_labels = list(generator.class_indices.keys())
    pretty_labels = [f"{i+1}-{lbl}" for i, lbl in enumerate(raw_labels)]

    # Classification report with precision, recall, f1-score
    report = classification_report(trues, preds, target_names=pretty_labels, output_dict=True)
    report_df = pd.DataFrame(report).T.round(2)

    summary_labels = ['accuracy', 'macro avg', 'weighted avg']
    class_labels = [r for r in report_df.index if r not in summary_labels]
    report_df = report_df.loc[class_labels + summary_labels]

    print(f"\nVGG16 {set_name} Classification Report:\n")
    print(report_df.to_string())

    # Macro-average ROC AUC
    y_true_oh = tf.keras.utils.to_categorical(trues, num_classes=generator.num_classes)
    macro_auc = roc_auc_score(y_true_oh, probs, average='macro', multi_class='ovo')

    # Summary metrics
    f1 = f1_score(trues, preds, average='macro')
    precision = precision_score(trues, preds, average='macro')
    recall = recall_score(trues, preds, average='macro')

    print(f"\nVGG16 Model {set_name} Metrics:")
    print(f"VGG16 Model: {set_name} F1 Score: {f1:.4f}")
    print(f"VGG16 Model: {set_name} Precision: {precision:.4f}")
    print(f"VGG16 Model: {set_name} Recall: {recall:.4f}")
    print(f"VGG16 Model: {set_name} AUC: {macro_auc:.4f}\n")

    return report_df

train_report_df = evaluate_and_report_vgg(vgg_model, vgg_train_iter, "Train")
val_report_df   = evaluate_and_report_vgg(vgg_model, vgg_val_iter, "Validation")
test_report_df  = evaluate_and_report_vgg(vgg_model, vgg_test_iter, "Test")
# Out:
# Evaluating Train set...
#
# VGG16 Train Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.12    0.12      0.12   295.00
# 2-2-Food Organics             0.09    0.09      0.09   263.00
# 3-3-Glass                     0.10    0.11      0.11   269.00
# 4-4-Metal                     0.18    0.18      0.18   506.00
# 5-5-Miscellaneous Trash       0.08    0.09      0.09   317.00
# 6-6-Paper                     0.09    0.09      0.09   320.00
# 7-7-Plastic                   0.19    0.18      0.19   589.00
# 8-8-Textile Trash             0.06    0.06      0.06   204.00
# 9-9-Vegetation                0.09    0.10      0.10   279.00
# accuracy                      0.12    0.12      0.12     0.12
# macro avg                     0.11    0.11      0.11  3042.00
# weighted avg                  0.13    0.12      0.12  3042.00
#
# VGG16 Model Train Metrics:
# VGG16 Model: Train F1 Score: 0.1118
# VGG16 Model: Train Precision: 0.1118
# VGG16 Model: Train Recall: 0.1118
# VGG16 Model: Train AUC: 0.5016
#
#
# Evaluating Validation set...
#
# VGG16 Validation Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.76    0.78      0.77    73.00
# 2-2-Food Organics             0.83    0.91      0.87    65.00
# 3-3-Glass                     0.91    0.90      0.90    67.00
# 4-4-Metal                     0.78    0.81      0.80   126.00
# 5-5-Miscellaneous Trash       0.76    0.72      0.74    79.00
# 6-6-Paper                     0.91    0.80      0.85    80.00
# 7-7-Plastic                   0.77    0.73      0.75   147.00
# 8-8-Textile Trash             0.76    0.78      0.77    50.00
# 9-9-Vegetation                0.87    0.97      0.92    69.00
# accuracy                      0.81    0.81      0.81     0.81
# macro avg                     0.82    0.82      0.82   756.00
# weighted avg                  0.81    0.81      0.81   756.00
#
# VGG16 Model Validation Metrics:
# VGG16 Model: Validation F1 Score: 0.8190
# VGG16 Model: Validation Precision: 0.8178
# VGG16 Model: Validation Recall: 0.8223
# VGG16 Model: Validation AUC: 0.9776
#
#
# Evaluating Test set...
# /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# VGG16 Test Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.83    0.76      0.79    93.00
# 2-2-Food Organics             0.83    0.84      0.84    83.00
# 3-3-Glass                     0.65    0.60      0.62    84.00
# 4-4-Metal                     0.78    0.83      0.80   158.00
# 5-5-Miscellaneous Trash       0.50    0.55      0.52    99.00
# 6-6-Paper                     0.87    0.82      0.85   100.00
# 7-7-Plastic                   0.72    0.75      0.73   185.00
# 8-8-Textile Trash             0.75    0.72      0.74    64.00
# 9-9-Vegetation                0.90    0.85      0.88    88.00
# accuracy                      0.75    0.75      0.75     0.75
# macro avg                     0.76    0.75      0.75   954.00
# weighted avg                  0.76    0.75      0.75   954.00
#
# VGG16 Model Test Metrics:
# VGG16 Model: Test F1 Score: 0.7518
# VGG16 Model: Test Precision: 0.7591
# VGG16 Model: Test Recall: 0.7460
# VGG16 Model: Test AUC: 0.9589

# %% [markdown]
# - - -

# %% [markdown]
# # Next Model - EfficientNetb0.

# %%
DATA_ROOT: Path        = Path("../data/WasteSplit")
IMAGE_SHAPE: Tuple[int, int] = (224, 224)
BATCH_SIZE: int        = 5
EPOCH_COUNT: int       = 100

#EfficientNet‑Style Preprocessor
effnet_preprocessor = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    rotation_range=25,            # random rotations up to ±25°
    width_shift_range=0.2,        # horizontal shifts
    height_shift_range=0.2,       # vertical shifts
    zoom_range=0.15,              # random zooms
    shear_range=0.1,              # slight shearing
    brightness_range=(0.85, 1.15),# brightness jitter
    horizontal_flip=True          # random flips
)

# Loader Factory
def make_data_loader(split: str, shuffle: bool = False):
    """
    Creates an iterator for one of ['train','val','test'].
    """
    folder = DATA_ROOT / split
    return effnet_preprocessor.flow_from_directory(
        directory=str(folder),
        target_size=IMAGE_SHAPE,
        batch_size=BATCH_SIZE,
        class_mode="categorical",
        shuffle=shuffle
    )
train_loader = make_data_loader("train", shuffle=True)
val_loader   = make_data_loader("val",   shuffle=False)
test_loader  = make_data_loader("test",  shuffle=False)
# Out:
# Found 3042 images belonging to 9 classes.
# Found 756 images belonging to 9 classes.
# Found 954 images belonging to 9 classes.

# %%
pip install -U efficientnet
# Out:
# Requirement already satisfied: efficientnet in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (1.1.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from efficientnet) (0.24.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.26.4)
# Requirement already satisfied: h5py in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.14.0)
# Requirement already satisfied: scipy>=1.9 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from scikit-image->efficientnet) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from scikit-image->efficientnet) (3.2.1)
# Requirement already satisfied: pillow>=9.1 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from scikit-image->efficientnet) (11.3.0)
# Requirement already satisfied: imageio>=2.33 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from scikit-image->efficientnet) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from scikit-image->efficientnet) (2024.8.30)
# Requirement already satisfied: packaging>=21 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from scikit-image->efficientnet) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages (from scikit-image->efficientnet) (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
ROOT = Path("../data/WasteSplit")
H, W = 224, 224
BATCH, EPOCHS = 5, 100
LR, L2_REG, PATIENCE = 1e-4, 1e-2, 40

# Explicit Generators
def make_gen(subdir, augment=False):
    folder = ROOT / subdir
    if augment:
        gen = ImageDataGenerator(
            preprocessing_function=tf.keras.applications.resnet.preprocess_input,
            rotation_range=20, width_shift_range=0.2, height_shift_range=0.2,
            zoom_range=0.2, brightness_range=(0.8,1.2), horizontal_flip=True
        )
    else:
        gen = ImageDataGenerator(
            preprocessing_function=tf.keras.applications.resnet.preprocess_input
        )
    return gen.flow_from_directory(
        directory=str(folder),
        target_size=(H, W),
        batch_size=BATCH,
        class_mode="categorical",
        shuffle=(subdir=="train")
    )

train_loader = make_gen("train", augment=True)
val_loader   = make_gen("val",   augment=True)
test_loader  = make_gen("test",  augment=False)

# ResNet101 + head
backbone = tf.keras.applications.ResNet101(
    weights="imagenet", include_top=False, input_shape=(H,W,3), name="resnet101_base"
)
backbone.trainable = False

def block(x, units, tag):
    x = layers.Dense(units, kernel_regularizer=l2(L2_REG), name=f"{tag}_dense")(x)
    x = layers.BatchNormalization(name=f"{tag}_bn")(x)
    return layers.Activation("relu", name=f"{tag}_act")(x)

x = layers.GlobalAveragePooling2D(name="gap")(backbone.output)
x = block(x, 256, "blk1")
x = block(x, 128, "blk2")
x = layers.Dropout(0.2, name="drop")(x)
x = block(x,  64, "blk3")

output = layers.Dense(
    train_loader.num_classes,
    activation="softmax",
    name="predictions"
)(x)

model = models.Model(backbone.input, output, name="ResNet101_Waste")
model.compile(
    optimizer=optimizers.Adam(LR),
    loss="categorical_crossentropy",
    metrics=["accuracy", AUC(name="auc")]   # added AUC metric
)

# Train with EarlyStopping
es = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=PATIENCE,
    restore_best_weights=True,
    verbose=1
)
history = model.fit(
    train_loader,
    validation_data=val_loader,
    epochs=EPOCHS,
    callbacks=[es]
)
# Out:
# Found 3042 images belonging to 9 classes.
# Found 756 images belonging to 9 classes.
# Found 954 images belonging to 9 classes.
# Epoch 1/100
# /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 46s 66ms/step - accuracy: 0.1970 - auc: 0.6308 - loss: 9.1797 - val_accuracy: 0.6151 - val_auc: 0.9107 - val_loss: 7.8476
# Epoch 2/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 34s 56ms/step - accuracy: 0.4820 - auc: 0.8647 - loss: 7.9680 - val_accuracy: 0.6627 - val_auc: 0.9438 - val_loss: 7.0986
# Epoch 3/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 34s 56ms/step - accuracy: 0.5649 - auc: 0.8987 - loss: 7.2788 - val_accuracy: 0.7354 - val_auc: 0.9580 - val_loss: 6.4595
# Epoch 4/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - accuracy: 0.6219 - auc: 0.9212 - loss: 6.6428 - val_accuracy: 0.7434 - val_auc: 0.9639 - val_loss: 5.9087
# Epoch 5/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 34s 57ms/step - accuracy: 0.6453 - auc: 0.9237 - loss: 6.1201 - val_accuracy: 0.7619 - val_auc: 0.9689 - val_loss: 5.4032
# Epoch 6/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 34s 56ms/step - accuracy: 0.6811 - auc: 0.9386 - loss: 5.5860 - val_accuracy: 0.7870 - val_auc: 0.9730 - val_loss: 4.9349
# Epoch 7/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.6977 - auc: 0.9480 - loss: 5.1137 - val_accuracy: 0.7817 - val_auc: 0.9716 - val_loss: 4.5799
# Epoch 8/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.7139 - auc: 0.9528 - loss: 4.7073 - val_accuracy: 0.7923 - val_auc: 0.9735 - val_loss: 4.2203
# Epoch 9/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 563s 925ms/step - accuracy: 0.7253 - auc: 0.9586 - loss: 4.3466 - val_accuracy: 0.8029 - val_auc: 0.9786 - val_loss: 3.8596
# Epoch 10/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 399s 656ms/step - accuracy: 0.7215 - auc: 0.9548 - loss: 4.0754 - val_accuracy: 0.8042 - val_auc: 0.9793 - val_loss: 3.6097
# Epoch 11/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - accuracy: 0.7293 - auc: 0.9608 - loss: 3.7833 - val_accuracy: 0.8267 - val_auc: 0.9821 - val_loss: 3.3417
# Epoch 12/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - accuracy: 0.7495 - auc: 0.9646 - loss: 3.5133 - val_accuracy: 0.8228 - val_auc: 0.9790 - val_loss: 3.1655
# Epoch 13/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - accuracy: 0.7668 - auc: 0.9664 - loss: 3.2860 - val_accuracy: 0.8069 - val_auc: 0.9817 - val_loss: 2.9546
# Epoch 14/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 37s 60ms/step - accuracy: 0.7558 - auc: 0.9657 - loss: 3.1139 - val_accuracy: 0.8148 - val_auc: 0.9801 - val_loss: 2.8088
# Epoch 15/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 37s 61ms/step - accuracy: 0.7565 - auc: 0.9646 - loss: 2.9644 - val_accuracy: 0.8333 - val_auc: 0.9827 - val_loss: 2.6225
# Epoch 16/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 37s 60ms/step - accuracy: 0.7713 - auc: 0.9704 - loss: 2.7714 - val_accuracy: 0.8241 - val_auc: 0.9828 - val_loss: 2.4927
# Epoch 17/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 36s 58ms/step - accuracy: 0.
100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.8704 - auc: 0.9878 - loss: 0.8897 - val_accuracy: 0.8452 - val_auc: 0.9833 - val_loss: 0.9378
# Epoch 83/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.8764 - auc: 0.9897 - loss: 0.8491 - val_accuracy: 0.8479 - val_auc: 0.9810 - val_loss: 0.9689
# Epoch 84/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - accuracy: 0.8608 - auc: 0.9879 - loss: 0.8888 - val_accuracy: 0.8598 - val_auc: 0.9859 - val_loss: 0.9090
# Epoch 85/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - accuracy: 0.8596 - auc: 0.9868 - loss: 0.8876 - val_accuracy: 0.8571 - val_auc: 0.9799 - val_loss: 0.9687
# Epoch 86/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - accuracy: 0.8592 - auc: 0.9859 - loss: 0.8861 - val_accuracy: 0.8598 - val_auc: 0.9821 - val_loss: 0.9506
# Epoch 87/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - accuracy: 0.8787 - auc: 0.9899 - loss: 0.8471 - val_accuracy: 0.8347 - val_auc: 0.9819 - val_loss: 0.9492
# Epoch 88/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - accuracy: 0.8643 - auc: 0.9860 - loss: 0.8888 - val_accuracy: 0.8624 - val_auc: 0.9841 - val_loss: 0.8984
# Epoch 89/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.8700 - auc: 0.9869 - loss: 0.8571 - val_accuracy: 0.8426 - val_auc: 0.9821 - val_loss: 0.9478
# Epoch 90/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.8815 - auc: 0.9882 - loss: 0.8346 - val_accuracy: 0.8399 - val_auc: 0.9742 - val_loss: 1.0060
# Epoch 91/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.8802 - auc: 0.9913 - loss: 0.8077 - val_accuracy: 0.8519 - val_auc: 0.9787 - val_loss: 0.9842
# Epoch 92/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.8615 - auc: 0.9872 - loss: 0.8654 - val_accuracy: 0.8598 - val_auc: 0.9816 - val_loss: 0.9267
# Epoch 93/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.8851 - auc: 0.9890 - loss: 0.8230 - val_accuracy: 0.8571 - val_auc: 0.9789 - val_loss: 0.9569
# Epoch 94/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.8645 - auc: 0.9865 - loss: 0.8632 - val_accuracy: 0.8545 - val_auc: 0.9808 - val_loss: 0.9280
# Epoch 95/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.8777 - auc: 0.9909 - loss: 0.8094 - val_accuracy: 0.8690 - val_auc: 0.9841 - val_loss: 0.8831
# Epoch 96/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.8787 - auc: 0.9882 - loss: 0.8192 - val_accuracy: 0.8585 - val_auc: 0.9805 - val_loss: 0.9336
# Epoch 97/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 57ms/step - accuracy: 0.8679 - auc: 0.9907 - loss: 0.8179 - val_accuracy: 0.8492 - val_auc: 0.9817 - val_loss: 0.9187
# Epoch 98/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - accuracy: 0.8834 - auc: 0.9905 - loss: 0.7951 - val_accuracy: 0.8571 - val_auc: 0.9852 - val_loss: 0.8702
# Epoch 99/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 35s 58ms/step - accuracy: 0.8531 - auc: 0.9856 - loss: 0.8713 - val_accuracy: 0.8677 - val_auc: 0.9811 - val_loss: 0.8995
# Epoch 100/100
# 609/609 ━━━━━━━━━━━━━━━━━━━━ 36s 58ms/step - accuracy: 0.8689 - auc: 0.9871 - loss: 0.8481 - val_accuracy: 0.8598 - val_auc: 0.9855 - val_loss: 0.8638
# Restoring model weights from the end of the best epoch: 100.

# %%
# Convert EfficientNetB0 training history to DataFrame
eff_df = pd.DataFrame(history.history)

# 1‑based epoch index
epoch_nums = np.arange(1, eff_df.shape[0] + 1)

# Epoch with lowest validation loss
best_epoch = int(eff_df['val_loss'].idxmin()) + 1

# ─── Loss Plot 
plt.figure()
plt.plot(epoch_nums, eff_df['loss'],      label='Training Loss')
plt.plot(epoch_nums, eff_df['val_loss'],  label='Validation Loss')
plt.axvline(best_epoch, linestyle='--',   label=f'Best Epoch: {best_epoch}')
plt.title('EfficientNetB0 Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# ─── Accuracy Plot 
plt.figure()
plt.plot(epoch_nums, eff_df['accuracy'],     label='Training Accuracy')
plt.plot(epoch_nums, eff_df['val_accuracy'], label='Validation Accuracy')
plt.axvline(best_epoch, linestyle='--',      label=f'Best Epoch: {best_epoch}')
plt.title('EfficientNetB0 Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# ─── AUC Plot 
train_aucs = eff_df['auc'].to_numpy()
val_aucs   = eff_df['val_auc'].to_numpy()

plt.figure()
plt.plot(epoch_nums, train_aucs, label='Training AUC')
plt.plot(epoch_nums, val_aucs,   label='Validation AUC')
plt.axvline(best_epoch, linestyle='--',    label=f'Best Epoch: {best_epoch}')
plt.title('EfficientNetB0 AUC per Epoch')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_auc_score
import tensorflow as tf

def evaluate_and_report(model, generator, set_name, model_name="EfficientNetB0"):
    print(f"\nEvaluating {model_name} on {set_name} set...")

    # Predictions
    probs = model.predict(generator, verbose=0)
    preds = np.argmax(probs, axis=1)
    trues = generator.classes

    # Class label formatting
    raw_labels = list(generator.class_indices.keys())
    readable_labels = [f"{i+1}-{lbl}" for i, lbl in enumerate(raw_labels)]

    # Classification report
    report = classification_report(trues, preds, target_names=readable_labels, output_dict=True)
    report_df = pd.DataFrame(report).T.round(2)

    # Reordering for nicer display
    summary_rows = ['accuracy', 'macro avg', 'weighted avg']
    class_rows   = [r for r in report_df.index if r not in summary_rows]
    report_df    = report_df.loc[class_rows + summary_rows]

    print(f"\n{model_name} {set_name} Classification Report:\n")
    print(report_df.to_string())

    # One-hot encoding for AUC
    y_true_oh = tf.keras.utils.to_categorical(trues, num_classes=generator.num_classes)
    macro_auc = roc_auc_score(y_true_oh, probs, average='macro', multi_class='ovo')

    # Summary metrics
    f1        = f1_score(trues, preds, average='macro')
    precision = precision_score(trues, preds, average='macro')
    recall    = recall_score(trues, preds, average='macro')

    print(f"\n{model_name} {set_name} Set Metrics:")
    print(f"{model_name}: {set_name} F1 Score: {f1:.4f}")
    print(f"{model_name}: {set_name} Precision: {precision:.4f}")
    print(f"{model_name}: {set_name} Recall: {recall:.4f}")
    print(f"{model_name}: {set_name} AUC: {macro_auc:.4f}\n")

    return report_df

# === Usage Example (make sure your generators are defined and use shuffle=False) ===
train_report_df = evaluate_and_report(model, train_loader, "Train", "EfficientNetB0")
val_report_df   = evaluate_and_report(model, val_loader, "Validation", "EfficientNetB0")
test_report_df  = evaluate_and_report(model, test_loader, "Test", "EfficientNetB0")
# Out:
# Evaluating EfficientNetB0 on Train set...
#
# EfficientNetB0 Train Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.08    0.07      0.08   295.00
# 2-2-Food Organics             0.09    0.09      0.09   263.00
# 3-3-Glass                     0.05    0.05      0.05   269.00
# 4-4-Metal                     0.14    0.15      0.15   506.00
# 5-5-Miscellaneous Trash       0.09    0.09      0.09   317.00
# 6-6-Paper                     0.11    0.11      0.11   320.00
# 7-7-Plastic                   0.23    0.24      0.24   589.00
# 8-8-Textile Trash             0.07    0.07      0.07   204.00
# 9-9-Vegetation                0.08    0.08      0.08   279.00
# accuracy                      0.12    0.12      0.12     0.12
# macro avg                     0.11    0.11      0.11  3042.00
# weighted avg                  0.12    0.12      0.12  3042.00
#
# EfficientNetB0 Train Set Metrics:
# EfficientNetB0: Train F1 Score: 0.1058
# EfficientNetB0: Train Precision: 0.1058
# EfficientNetB0: Train Recall: 0.1059
# EfficientNetB0: Train AUC: 0.4953
#
#
# Evaluating EfficientNetB0 on Validation set...
#
# EfficientNetB0 Validation Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.91    0.84      0.87    73.00
# 2-2-Food Organics             0.91    0.89      0.90    65.00
# 3-3-Glass                     0.92    0.87      0.89    67.00
# 4-4-Metal                     0.89    0.94      0.91   126.00
# 5-5-Miscellaneous Trash       0.81    0.78      0.79    79.00
# 6-6-Paper                     0.92    0.89      0.90    80.00
# 7-7-Plastic                   0.81    0.84      0.83   147.00
# 8-8-Textile Trash             0.81    0.86      0.83    50.00
# 9-9-Vegetation                0.93    0.94      0.94    69.00
# accuracy                      0.87    0.87      0.87     0.87
# macro avg                     0.88    0.87      0.87   756.00
# weighted avg                  0.87    0.87      0.87   756.00
#
# EfficientNetB0 Validation Set Metrics:
# EfficientNetB0: Validation F1 Score: 0.8749
# EfficientNetB0: Validation Precision: 0.8788
# EfficientNetB0: Validation Recall: 0.8720
# EfficientNetB0: Validation AUC: 0.9855
#
#
# Evaluating EfficientNetB0 on Test set...
# /opt/anaconda3/envs/tf_env/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# EfficientNetB0 Test Classification Report:
#
#                          precision  recall  f1-score  support
# 1-1-Cardboard                 0.86    0.82      0.84    93.00
# 2-2-Food Organics             0.78    0.88      0.83    83.00
# 3-3-Glass                     0.81    0.71      0.76    84.00
# 4-4-Metal                     0.67    0.92      0.77   158.00
# 5-5-Miscellaneous Trash       0.63    0.42      0.51    99.00
# 6-6-Paper                     0.89    0.94      0.91   100.00
# 7-7-Plastic                   0.83    0.76      0.79   185.00
# 8-8-Textile Trash             0.73    0.80      0.76    64.00
# 9-9-Vegetation                1.00    0.76      0.86    88.00
# accuracy                      0.79    0.79      0.79     0.79
# macro avg                     0.80    0.78      0.78   954.00
# weighted avg                  0.79    0.79      0.78   954.00
#
# EfficientNetB0 Test Set Metrics:
# EfficientNetB0: Test F1 Score: 0.7825
# EfficientNetB0: Test Precision: 0.7997
# EfficientNetB0: Test Recall: 0.7800
# EfficientNetB0: Test AUC: 0.9723

# %%
EfficientNetB0_model = model
EfficientNetB0_model.save('EfficientNetB0_model_final.keras')

# %% [markdown]
# - - -

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import classification_report, roc_auc_score

resnet50_model      = model      # e.g. your ResNet50 instance
resnet101_model     = resnet101_model     # e.g. classifier_net or model
vgg16_model         = vgg_model           # your VGG16 instance
efficientnetb0_model = EfficientNetB0_model      # your EfficientNetB0 instance

models = {
    "ResNet50":       resnet50_model,
    "ResNet101":      resnet101_model,
    "VGG16":          vgg16_model,
    "EfficientNetB0": efficientnetb0_model
}

loaders = {
    "Train":      train_loader,
    "Validation": val_loader,
    "Test":       test_loader
}

records = []
for name, mdl in models.items():
    for split, loader in loaders.items():

        probs  = mdl.predict(loader, verbose=0)
        preds  = np.argmax(probs, axis=1)
        trues  = loader.classes
        rep    = classification_report(trues, preds, output_dict=True)
        p      = rep["macro avg"]["precision"]
        r      = rep["macro avg"]["recall"]
        f1     = rep["macro avg"]["f1-score"]

        y_true_oh = tf.keras.utils.to_categorical(trues, num_classes=loader.num_classes)
        auc    = roc_auc_score(y_true_oh, probs, average="macro", multi_class="ovo")

        records.append({
            "Model":   name,
            "Split":   split,
            "Precision": round(p,  2),
            "Recall":    round(r,  2),
            "F1‑score":  round(f1, 2),
            "AUC":       round(auc,2)   
        })

df_summary = pd.DataFrame(records)
table = df_summary.pivot(
    index="Model",
    columns="Split",
    values=["Precision","Recall","F1‑score","AUC"]
)
print(table)
# Out:
#                Precision                  Recall                  F1‑score  \
# Split               Test Train Validation   Test Train Validation     Test
# Model
# EfficientNetB0      0.80  0.10       0.87   0.78  0.10       0.87     0.78
# ResNet101           0.82  0.11       0.86   0.77  0.11       0.85     0.78
# ResNet50            0.80  0.11       0.87   0.78  0.11       0.86     0.78
# VGG16               0.75  0.11       0.81   0.74  0.11       0.82     0.74
#
#                                   AUC
# Split          Train Validation  Test Train Validation
# Model
# EfficientNetB0  0.10       0.87  0.97  0.50       0.99
# ResNet101       0.11       0.86  0.97  0.50       0.98
# ResNet50        0.11       0.86  0.97  0.49       0.98
# VGG16           0.11       0.81  0.96  0.49       0.98

# %% [markdown]
# Although ResNet101 edged out ResNet50 on raw precision (0.82 vs. 0.80), the overall balance of metrics and efficiency tips the scales in favor of ResNet50 as our second choice after EfficientNetB0:
#
# 1. **EfficientNetB0** sits firmly in first place—it ties for the highest test‑set F1 (0.78) and AUC (0.97) but also boasts the top validation AUC (0.99) and competitive recall (0.78). Its substantially smaller footprint and faster inference make it the clear winner.
# 2. **ResNet50** comes next: it matches EfficientNetB0 on F1 (0.78) and AUC (0.97) on the test set, yet is lighter and quicker than its deeper sibling, ResNet101. That combination of near‑top accuracy plus efficiency puts it in second.
# 3. **ResNet101** is third: it achieves the highest precision on the test split (0.82) but, being a much larger network, comes with longer training and inference times—and its F1 (0.78) and AUC (0.97) are no better than ResNet50’s.
# 4. **VGG16** rounds out the list with lower F1 (0.74) and AUC (0.96). Its heavier architecture and comparatively weaker performance place it last.
#
# So, ranking by the best blend of test metrics and practical efficiency yields:
# **EfficientNetB0 → ResNet50 → ResNet101 → VGG16**.

# %% [markdown]
# ## References
#
# 1. **Keras ImageDataGenerator**
#    [https://www.tensorflow.org/api\_docs/python/tf/keras/preprocessing/image/ImageDataGenerator](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator)
#
# 2. **TensorFlow EfficientNetB0**
#    [https://www.tensorflow.org/api\_docs/python/tf/keras/applications/EfficientNetB0](https://www.tensorflow.org/api_docs/python/tf/keras/applications/EfficientNetB0)
#
# 3. **Keras AUC Metric**
#    [https://www.tensorflow.org/api\_docs/python/tf/keras/metrics/AUC](https://www.tensorflow.org/api_docs/python/tf/keras/metrics/AUC)
#
# 4. **scikit‑learn classification\_report**
#    [https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification\_report.html](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
#
# 5. **Keras EarlyStopping Callback**
#    [https://www.tensorflow.org/api\_docs/python/tf/keras/callbacks/EarlyStopping](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping)
