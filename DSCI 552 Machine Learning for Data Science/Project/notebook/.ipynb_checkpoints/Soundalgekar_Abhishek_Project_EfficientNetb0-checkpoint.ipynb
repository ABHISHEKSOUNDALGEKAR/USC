# %% [markdown]
# <center><h1>Soundalgekar_Abhishek_Project_EfficientNetb0</h1></center>

# %% [markdown]
# Name: Abhishek Soundalgekar
# <br>
# Github Username: ABHISHEK SOUNDALGEKAR
# <br>
# USC ID: 2089011000

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.metrics import classification_report
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from typing import Tuple
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import (
    GlobalAveragePooling2D,
    Dense,
    BatchNormalization,
    Dropout,
    Activation
)

from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers     import GlobalAveragePooling2D, Dense, BatchNormalization, Dropout, Activation
from tensorflow.keras.models     import Model
from tensorflow.keras.optimizers import Adam as AdamOpt
from tensorflow.keras.callbacks  import EarlyStopping
from tensorflow.keras.regularizers import l2

# %%
DATA_ROOT: Path        = Path("../data/WasteSplit")
IMAGE_SHAPE: Tuple[int, int] = (224, 224)
BATCH_SIZE: int        = 5
EPOCH_COUNT: int       = 100

#EfficientNet‑Style Preprocessor
effnet_preprocessor = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    rotation_range=25,            # random rotations up to ±25°
    width_shift_range=0.2,        # horizontal shifts
    height_shift_range=0.2,       # vertical shifts
    zoom_range=0.15,              # random zooms
    shear_range=0.1,              # slight shearing
    brightness_range=(0.85, 1.15),# brightness jitter
    horizontal_flip=True          # random flips
)

# Loader Factory
def make_data_loader(split: str, shuffle: bool = False):
    """
    Creates an iterator for one of ['train','val','test'].
    """
    folder = DATA_ROOT / split
    return effnet_preprocessor.flow_from_directory(
        directory=str(folder),
        target_size=IMAGE_SHAPE,
        batch_size=BATCH_SIZE,
        class_mode="categorical",
        shuffle=shuffle
    )
train_loader = make_data_loader("train", shuffle=True)
val_loader   = make_data_loader("val",   shuffle=False)
test_loader  = make_data_loader("test",  shuffle=False)
# Out:
# Found 3323 images belonging to 9 classes.
# Found 710 images belonging to 9 classes.
# Found 719 images belonging to 9 classes.

# %%
pip install -U efficientnet
# Out:
# Requirement already satisfied: efficientnet in c:\users\chalu\appdata\local\programs\python\python310\lib\site-packages (1.1.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in c:\users\chalu\appdata\local\programs\python\python310\lib\site-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in c:\users\chalu\appdata\local\programs\python\python310\lib\site-packages (from efficientnet) (0.25.2)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\chalu\appdata\local\programs\python\python310\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (2.1.3)
# Requirement already satisfied: h5py in c:\users\chalu\appdata\local\programs\python\python310\lib\site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.14.0)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\chalu\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->efficientnet) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in c:\users\chalu\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->efficientnet) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in c:\users\chalu\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->efficientnet) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\chalu\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->efficientnet) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\chalu\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->efficientnet) (2025.5.10)
# Requirement already satisfied: packaging>=21 in c:\users\chalu\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->efficientnet) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\chalu\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->efficientnet) (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import efficientnet.tfkeras as efn
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.regularizers import l2

# --- Configuration ---
ROOT = Path("../data/WasteSplit")
H, W = 224, 224
BATCH, EPOCHS = 5, 100
LR, L2_REG, PATIENCE = 1e-4, 1e-2, 40

# --- Explicit Generators (no validation_split) ---
def make_gen(subdir, augment=False):
    folder = ROOT / subdir
    if augment:
        gen = ImageDataGenerator(
            preprocessing_function=tf.keras.applications.resnet.preprocess_input,
            rotation_range=20, width_shift_range=0.2, height_shift_range=0.2,
            zoom_range=0.2, brightness_range=(0.8,1.2), horizontal_flip=True
        )
    else:
        gen = ImageDataGenerator(
            preprocessing_function=tf.keras.applications.resnet.preprocess_input
        )
    return gen.flow_from_directory(
        directory=str(folder),
        target_size=(H, W),
        batch_size=BATCH,
        class_mode="categorical",
        shuffle=(subdir=="train")
    )

train_loader = make_gen("train", augment=True)
val_loader   = make_gen("val",   augment=True)
test_loader  = make_gen("test",  augment=False)

# --- Build ResNet101 + head ---
backbone = tf.keras.applications.ResNet101(
    weights="imagenet", include_top=False, input_shape=(H,W,3), name="resnet101_base"
)
backbone.trainable = False

def block(x, units, tag):
    x = layers.Dense(units, kernel_regularizer=l2(L2_REG), name=f"{tag}_dense")(x)
    x = layers.BatchNormalization(name=f"{tag}_bn")(x)
    return layers.Activation("relu", name=f"{tag}_act")(x)

x = layers.GlobalAveragePooling2D(name="gap")(backbone.output)
x = block(x, 256, "blk1")
x = block(x, 128, "blk2")
x = layers.Dropout(0.2, name="drop")(x)
x = block(x,  64, "blk3")

output = layers.Dense(
    train_loader.num_classes,
    activation="softmax",
    name="predictions"
)(x)

model = models.Model(backbone.input, output, name="ResNet101_Waste")
model.compile(
    optimizer=optimizers.Adam(LR),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# ---
100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 320s 481ms/step - accuracy: 0.8676 - loss: 0.8285 - val_accuracy: 0.8662 - val_loss: 0.8182
# Epoch 93/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 322s 485ms/step - accuracy: 0.8619 - loss: 0.8355 - val_accuracy: 0.8606 - val_loss: 0.9207
# Epoch 94/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 325s 489ms/step - accuracy: 0.8866 - loss: 0.8032 - val_accuracy: 0.8620 - val_loss: 0.8802
# Epoch 95/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 323s 485ms/step - accuracy: 0.8578 - loss: 0.8571 - val_accuracy: 0.8746 - val_loss: 0.8433
# Epoch 96/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 323s 486ms/step - accuracy: 0.8578 - loss: 0.8468 - val_accuracy: 0.8366 - val_loss: 0.9018
# Epoch 97/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 323s 486ms/step - accuracy: 0.8696 - loss: 0.8333 - val_accuracy: 0.8746 - val_loss: 0.8552
# Epoch 98/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 322s 484ms/step - accuracy: 0.8695 - loss: 0.8421 - val_accuracy: 0.8634 - val_loss: 0.8247
# Epoch 99/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 326s 491ms/step - accuracy: 0.8517 - loss: 0.8329 - val_accuracy: 0.8704 - val_loss: 0.8117
# Epoch 100/100
# 665/665 ━━━━━━━━━━━━━━━━━━━━ 326s 491ms/step - accuracy: 0.8614 - loss: 0.8433 - val_accuracy: 0.8521 - val_loss: 0.8206
# Restoring model weights from the end of the best epoch: 90.

# %%
eff_df = pd.DataFrame(history.history)

#Create a 1‑based epoch index
epoch_nums = np.arange(1, eff_df.shape[0] + 1)

#Find which epoch yielded the lowest validation loss
best_epoch = int(eff_df['val_loss'].idxmin()) + 1

#Plot Loss
plt.figure()
plt.plot(epoch_nums, eff_df['loss'],       label='Training Loss')
plt.plot(epoch_nums, eff_df['val_loss'],   label='Validation Loss')
plt.axvline(best_epoch, linestyle='--',    label=f'Best Epoch: {best_epoch}')
plt.title('EfficientNetB0 Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

#Plot Accuracy
plt.figure()
plt.plot(epoch_nums, eff_df['accuracy'],     label='Training Accuracy')
plt.plot(epoch_nums, eff_df['val_accuracy'], label='Validation Accuracy')
plt.axvline(best_epoch, linestyle='--',      label=f'Best Epoch: {best_epoch}')
plt.title('EfficientNetB0 Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3 import matplotlib.pyplot as plt
#       5 # 1) Turn the EfficientNetB0 fit history into a DataFrame
# ----> 6 eff_df = pd.DataFrame(history.history)
#       8 # 2) Create a 1‑based epoch index
#       9 epoch_nums = np.arange(1, eff_df.shape[0] + 1)
#
# NameError: name 'history' is not defined

# %%
probabilities = model.predict(test_loader, verbose=0)
pred_indices  = np.argmax(probabilities, axis=1)
true_indices  = test_loader.classes

raw_labels   = list(test_loader.class_indices.keys())
readable_lbl = [f"{i+1}-{lbl}" for i, lbl in enumerate(raw_labels)]

#classification report as a dictionary
report_dict = classification_report(
    y_true=true_indices,
    y_pred=pred_indices,
    target_names=readable_lbl,
    output_dict=True
)

#DataFrame and round metrics
report_table = pd.DataFrame(report_dict).T.round(2)

#class rows first, then summary rows
summary_rows = ['accuracy', 'macro avg', 'weighted avg']
class_rows   = [r for r in report_table.index if r not in summary_rows]
report_table = report_table.loc[class_rows + summary_rows]

print("\nEfficientNetB0 Test‑Set Classification Report:\n")
print(report_table.to_string())
# Out:
# KeyboardInterrupt

# %%
model.save('EfficientNetB0_model_final.keras')

# %% [markdown]
# EfficientNetB0 and Resnet50 model gives the best performance
