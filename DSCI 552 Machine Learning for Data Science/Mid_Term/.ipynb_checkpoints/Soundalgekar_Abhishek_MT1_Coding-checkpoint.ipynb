# %% [markdown]
# # DSCI 552 Mid-Term 1 Coding #

# %% [markdown]
# ### Name: Abhishek Soundalgekar
# ### USC ID: 2089011000

# %% [markdown]
# #### Programming Question: Predicting Housing Prices with Linear Regression Dataset: USA Housing.csv ####
# #### Dataset: https://www.kaggle.com/datasets/vedavyasv/usa-housing

# %% [markdown]
# #### In this problem, you will build a linear regression model to predict housing prices in the USA based on various features. You will use Python and scikit-learn for this task.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# ### (a) Data Exploration and Pre-processing

# %% [markdown]
# #### i. Load the USA Housing.csv dataset into a pandas DataFrame.

# %%
housing_df = pd.read_csv("../data/USA_Housing.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 housing_df = pd.read_csv("../data/USA_Housing.csv")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...
